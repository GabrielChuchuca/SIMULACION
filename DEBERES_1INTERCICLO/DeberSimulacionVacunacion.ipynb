# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielChuchuca/SIMULACION/blob/main/DeberSimulacionVacunacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# El proceso de vacunacion es el siguiente.
# * La persona llega 20 minutos antes de la hora de vacunacion
# * Ingresa a la cola/fila a que toque su turno
# - Tenemos un proceso de control en donde se toma los signos vitales y se valida que este dentro del padron (2-5 minutos)
# - Se procede al traslado a la cama/silla de vacunacion y se inyecta la dosis de la vacuna este proceso tarde entre (5-10 minutos).
# - Finalmente llevados a la salida entre (1-3 minutos).
#
# Finalmente generar las siguientes metricas/graficas:
# - Tiempo de espera promedio para cada persona.
# - Tiempo promedio total que requiere un paciente para ser vacunado.
# - Cuantos pacientes se atendieron.
# - Cuantos pacientes se quedaron sin atende

# %%
import simpy
import random
import matplotlib.pyplot as plt

# %%
# Maximo de vehiculos que puede recibir el negocio
MAX_VACUNAS = 57
# Total de numero de mesas para vacunacion
NUM_MESAS = 3
PACIENTES = 400
# Intervalo de tiempo en que llegan vehiculos (minutos)
INTERVALO_LLEGADA = 20 #minutos
# Tiempo de simulación
TIEMPO_SIMULACION = 480 #Minutos = 8 horas
INTERVALO = 10

# Creamos un diccionario para almacenar las horas en que se vacuna los pacientes
tiempo_vacunacion={}
#Diccionario para el numero de pacientes que han sido atendidos
p_vacunado =[]
#Diccionario para el numero de pacientes que no han sido atendidos
p_no_vacunado = []

# %%
class Centro(object):
    def __init__(self, environment, num_mesas, nombre):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.mesas = simpy.Resource(environment, num_mesas)
        self.nombre = nombre

    #Proceso de control, para toma de signos vitales y valida estar dentro del padron
    def control(self, paciente):
        t_con = random.randint(2,5) #Tenemos un proceso de control en donde se toma los signos vitales y se valida que este dentro del padron (2-5 minutos)
        yield self.env.timeout(t_con)
            
    #Para traslado a la cama/silla de vacunacion y se inyecta
    def vacunacion(self, paciente):
        t_vacunacion = random.randint(5,10) #Se procede al traslado a la cama/silla de vacunacion y se inyecta la dosis de la vacuna este proceso tarde entre (5-10 minutos).
        print("Tiempo tomado: ",t_vacunacion," para paciente: ",paciente)
        yield self.env.timeout(t_vacunacion)
        
        k = int(paciente.strip('Paciente-'))
        print("Paciente ",k)
        if k in tiempo_vacunacion:
            tiempo_vacunacion[k]=tiempo_vacunacion[k]+1
        else:
            tiempo_vacunacion[k]=t_vacunacion
            
    #Traslado para la salida del paciente
    def salida(self,paciente):
        t_salida = random.randint(1,3) #Finalmente llevados a la salida entre (1-3 minutos).
        yield self.env.timeout(t_salida)

# %%
def llegada(env, nombre, centro):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('Llega el paciente: %s a la hora %.2f.' % (nombre, env.now))
    
    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    with centro.mesas.request() as mesa:
        # Ocupamos la mesa de vacunacion
        yield mesa
        #Indicamos que el paciente se esta trasladando para ser vacunado
        print('Se traslada el paciente: %s a la hora %.2f.' % (nombre,env.now))
        #Procesamos el traslado del paciente
        yield env.process(centro.control(nombre))
        
        estado = random.randint(1,2)
        print("Sintomas: ",estado)
        if estado == 1:            
            p_no_vacunado.append(nombre)
        else:
            # Indicamos que paciente ingresa a la mesa de vacunacion
            print('Ingresa el paciente a las %s a la hora %.2f.' % (nombre, env.now))
            
            # Se realiza la vacunacion
            yield env.process(centro.vacunacion(nombre))
            # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
            print('Paciente [%s] vacunado a las %.2f.' % (nombre, env.now))
            p_vacunado.append(nombre)
            
        yield env.process(centro.salida(nombre))
        print('Paciente [%s] trasladado a la salida a las %.2f.' %(nombre,env.now))

# %%
def ejecucion(env, num_mesas, pacientes, intervalo):
    centro = Centro(env,num_mesas,"Coliseo UPS")
    for i in range(pacientes):
        env.process(llegada(env,'Paciente-%d'%(i+1), centro))
    while True:
        yield env.timeout(random.randint(intervalo-10,intervalo+10))
        i+=1
        env.process(llegada(env,'Paciente-%d'%(i+1), centro))

# %%
# Creamos el entorno de simulacion
env=simpy.Environment()
print("pacientes ", PACIENTES)
env.process(ejecucion(env, NUM_MESAS, PACIENTES, INTERVALO))
# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)
# Out:
# pacientes  400
# Llega el paciente: Paciente-1 a la hora 0.00.
# Llega el paciente: Paciente-2 a la hora 0.00.
# Llega el paciente: Paciente-3 a la hora 0.00.
# Llega el paciente: Paciente-4 a la hora 0.00.
# Llega el paciente: Paciente-5 a la hora 0.00.
# Llega el paciente: Paciente-6 a la hora 0.00.
# Llega el paciente: Paciente-7 a la hora 0.00.
# Llega el paciente: Paciente-8 a la hora 0.00.
# Llega el paciente: Paciente-9 a la hora 0.00.
# Llega el paciente: Paciente-10 a la hora 0.00.
# Llega el paciente: Paciente-11 a la hora 0.00.
# Llega el paciente: Paciente-12 a la hora 0.00.
# Llega el paciente: Paciente-13 a la hora 0.00.
# Llega el paciente: Paciente-14 a la hora 0.00.
# Llega el paciente: Paciente-15 a la hora 0.00.
# Llega el paciente: Paciente-16 a la hora 0.00.
# Llega el paciente: Paciente-17 a la hora 0.00.
# Llega el paciente: Paciente-18 a la hora 0.00.
# Llega el paciente: Paciente-19 a la hora 0.00.
# Llega el paciente: Paciente-20 a la hora 0.00.
# Llega el paciente: Paciente-21 a la hora 0.00.
# Llega el paciente: Paciente-22 a la hora 0.00.
# Llega el paciente: Paciente-23 a la hora 0.00.
# Llega el paciente: Paciente-24 a la hora 0.00.
# Llega el paciente: Paciente-25 a la hora 0.00.
# Llega el paciente: Paciente-26 a la hora 0.00.
# Llega el paciente: Paciente-27 a la hora 0.00.
# Llega el paciente: Paciente-28 a la hora 0.00.
# Llega el paciente: Paciente-29 a la hora 0.00.
# Llega el paciente: Paciente-30 a la hora 0.00.
# Llega el paciente: Paciente-31 a la hora 0.00.
# Llega el paciente: Paciente-32 a la hora 0.00.
# Llega el paciente: Paciente-33 a la hora 0.00.
# Llega el paciente: Paciente-34 a la hora 0.00.
# Llega el paciente: Paciente-35 a la hora 0.00.
# Llega el paciente: Paciente-36 a la hora 0.00.
# Llega el paciente: Paciente-37 a la hora 0.00.
# Llega el paciente: Paciente-38 a la hora 0.00.
# Llega el paciente: Paciente-39 a la hora 0.00.
# Llega el paciente: Paciente-40 a la hora 0.00.
# Llega el paciente: Paciente-41 a la hora 0.00.
# Llega el paciente: Paciente-42 a la hora 0.00.
# Llega el paciente: Paciente-43 a la hora 0.00.
# Llega el paciente: Paciente-44 a la hora 0.00.
# Llega el paciente: Paciente-45 a la hora 0.00.
# Llega el paciente: Paciente-46 a la hora 0.00.
# Llega el paciente: Paciente-47 a la hora 0.00.
# Llega el paciente: Paciente-48 a la hora 0.00.
# Llega el paciente: Paciente-49 a la hora 0.00.
# Llega el paciente: Paciente-50 a la hora 0.00.
# Llega el paciente: Paciente-51 a la hora 0.00.
# Llega el paciente: Paciente-52 a la hora 0.00.
# Llega el paciente: Paciente-53 a la hora 0.00.
# Llega el paciente: Paciente-54 a la hora 0.00.
# Llega el paciente: Paciente-55 a la hora 0.00.
# Llega el paciente: Paciente-56 a la hora 0.00.
# Llega el paciente: Paciente-57 a la hora 0.00.
# Llega el paciente: Paciente-58 a la hora 0.00.
# Llega el paciente: Paciente-59 a la hora 0.00.
# Llega el paciente: Paciente-60 a la hora 0.00.
# Llega el paciente: Paciente-61 a la hora 0.00.
# Llega el paciente: Paciente-62 a la hora 0.00.
# Llega el paciente: Paciente-63 a la hora 0.00.
# Llega el paciente: Paciente-64 a la hora 0.00.
# Llega el paciente: Paciente-65 a la hora 0.00.
# Llega el paciente: Paciente-66 a la hora 0.00.
# Llega el paciente: Paciente-67 a la hora 0.00.
# Llega el paciente: Paciente-68 a la hora 0.00.
# Llega el paciente: Paciente-69 a la hora 0.00.
# Llega el paciente: Paciente-70 a la hora 0.00.
# Llega el paciente: Paciente-71 a la hora 0.00.
# Llega el paciente: Paciente-72 a la hora 0.00.
# Llega el paciente: Paciente-73 a la hora 0.00.
# Llega el paciente: Paciente-74 a la hora 0.00.
# Llega el paciente: Paciente-75 a la hora 0.00.
# Llega el paciente: Paciente-76 a la hora 0.00.
# Llega el paciente: Paciente-77 a la hora 0.00.
# Llega el paciente: Paciente-78 a la hora 0.00.
# Llega el paciente: Paciente-79 a la hora 0.00.
# Llega el paciente: Paciente-80 a la hora 0.00.
# Llega el paciente: Paciente-81 a la hora 0.00.
# Llega el paciente: Paciente-82 a la hora 0.00.
# Llega el paciente: Paciente-83 a la hora 0.00.
# Llega el paciente: Paciente-84 a la hora 0.00.
# Llega el paciente: Paciente-85 a la hora 0.00.
# Llega el paciente: Paciente-86 a la hora 0.00.
# Llega el paciente: Paciente-87 a la hora 0.00.
# Llega el paciente: Paciente-88 a la hora 0.00.
# Llega el paciente: Paciente-89 a la hora 0.00.
# Llega el paciente: Paciente-90 a la hora 0.00.
# Llega el paciente: Paciente-91 a la hora 0.00.
# Llega el paciente: Paciente-92 a la hora 0.00.
# Llega el paciente: Paciente-93 a la hora 0.00.
# Llega el paciente: Paciente-94 a la hora 0.00.
# Llega el paciente: Paciente-95 a la hora 0.00.
# Llega el paciente: Paciente-96 a la hora 0.00.
# Llega el paciente: Paciente-97 a la hora 0.00.
# Llega el paciente: Paciente-98 a la hora 0.00.
# Llega el paciente: Paciente-99 a la hora 0.00.
# Llega el paciente: Paciente-100 a la hora 0.00.
# Llega el paciente: Paciente-101 a la hora 0.00.
# Llega el paciente: Paciente-102 a la hora 0.00.
# Llega el paciente: Paciente-103 a la hora 0.00.
# Llega el paciente: Paciente-104 a la hora 0.00.
# Llega el paciente: Paciente-105 a la hora 0.00.
# Llega el paciente: Paciente-106 a la hora 0.00.
# Llega el paciente: Paciente-107 a la hora 0.00.
# Llega el paciente: Paciente-108 a la hora 0.00.
# Llega el paciente: Paciente-109 a la hora 0.00.
# Llega el paciente: Paciente-110 a la hora 0.00.
# Llega el paciente: Paciente-111 a la hora 0.00.
# Llega el paciente: Paciente-112 a la hora 0.00.
# Llega el paciente: Paciente-113 a la hora 0.00.
# Llega el paciente: Paciente-114 a la hora 0.00.
# Llega el paciente: Paciente-115 a la hora 0.00.
# Llega el paciente: Paciente-116 a la hora 0.00.
# Llega el paciente: Paciente-117 a la hora 0.00.
# Llega el paciente: Paciente-118 a la hora 0.00.
# Llega el paciente: Paciente-119 a la hora 0.00.
# Llega el paciente: Paciente-120 a la hora 0.00.
# Llega el paciente: Paciente-121 a la hora 0.00.
# Llega el paciente: Paciente-122 a la hora 0.00.
# Llega el paciente: Paciente-123 a la hora 0.00.
# Llega el paciente: Paciente-124 a la hora 0.00.
# Llega el paciente: Paciente-125 a la hora 0.00.
# Llega el paciente: Paciente-126 a la hora 0.00.
# Llega el paciente: Paciente-127 a la hora 0.00.
# Llega el paciente: Paciente-128 a la hora 0.00.
# Llega el paciente: Paciente-129 a la hora 0.00.
# Llega el paciente: Paciente-130 a la hora 0.00.
# Llega el paciente: Paciente-131 a la hora 0.00.
# Llega el paciente: Paciente-132 a la hora 0.00.
# Llega el paciente: Paciente-133 a la hora 0.00.
# Llega el paciente: Paciente-134 a la hora 0.00.
# Llega el paciente: Paciente-135 a la hora 0.00.
# Llega el paciente: Paciente-136 a la hora 0.00.
# Llega el paciente: Paciente-137 a la hora 0.00.
# Llega el paciente: Paciente-138 a la hora 0.00.
# Llega el paciente: Paciente-139 a la hora 0.00.
# Llega el paciente: Paciente-140 a la hora 0.00.
# Llega el paciente: Paciente-141 a la hora 0.00.
# Llega el paciente: Paciente-142 a la hora 0.00.
# Llega el paciente: Paciente-143 a la hora 0.00.
# Llega el paciente: Paciente-144 a la hora 0.00.
# Llega el paciente: Paciente-145 a la hora 0.00.
# Llega el paciente: Paciente-146 a la hora 0.00.
# Llega el paciente: Paciente-147 a la hora 0.00.
# Llega el paciente: Paciente-148 a la hora 0.00.
# Llega el paciente: Paciente-149 a la hora 0.00.
# Llega el paciente: Paciente-150 a la hora 0.00.
# Llega el paciente: Paciente-151 a la hora 0.00.
# Llega el paciente: Paciente-152 a la hora 0.00.
# Llega el paciente: Paciente-153 a la hora 0.00.
# Llega el paciente: Paciente-154 a la hora 0.00.
# Llega el paciente: Paciente-155 a la hora 0.00.
# Llega el paciente: Paciente-156 a la hora 0.00.
# Llega el paciente: Paciente-157 a la hora 0.00.
# Llega el paciente: Paciente-158 a la hora 0.00.
# Llega el paciente: Paciente-159 a la hora 0.00.
# Llega el paciente: Paciente-160 a la hora 0.00.
# Llega el paciente: Paciente-161 a la hora 0.00.
# Llega el paciente: Paciente-162 a la hora 0.00.
# Llega el paciente: Paciente-163 a la hora 0.00.
# Llega el paciente: Paciente-164 a la hora 0.00.
# Llega el paciente: Paciente-165 a la hora 0.00.
# Llega el paciente: Paciente-166 a la hora 0.00.
# Llega el paciente: Paciente-167 a la hora 0.00.
# Llega el paciente: Paciente-168 a la hora 0.00.
# Llega el paciente: Paciente-169 a la hora 0.00.
# Llega el paciente: Paciente-170 a la hora 0.00.
# Llega el paciente: Paciente-171 a la hora 0.00.
# Llega el paciente: Paciente-172 a la hora 0.00.
# Llega el paciente: Paciente-173 a la hora 0.00.
# Llega el paciente: Paciente-174 a la hora 0.00.
# Llega el paciente: Paciente-175 a la hora 0.00.
# Llega el paciente: Paciente-176 a la hora 0.00.
# Llega el paciente: Paciente-177 a la hora 0.00.
# Llega el paciente: Paciente-178 a la hora 0.00.
# Llega el paciente: Paciente-179 a la hora 0.00.
# Llega el paciente: Paciente-180 a la hora 0.00.
# Llega el paciente: Paciente-181 a la hora 0.00.
# Llega el paciente: Paciente-182 a la hora 0.00.
# Llega el paciente: Paciente-183 a la hora 0.00.
# Llega el paciente: Paciente-184 a la hora 0.00.
# Llega el paciente: Paciente-185 a la hora 0.00.
# Llega el paciente: Paciente-186 a la hora 0.00.
# Llega el paciente: Paciente-187 a la hora 0.00.
# Llega el paciente: Paciente-188 a la hora 0.00.
# Llega el paciente: Paciente-189 a la hora 0.00.
# Llega el paciente: Paciente-190 a la hora 0.00.
# Llega el paciente: Paciente-191 a la hora 0.00.
# Llega el paciente: Paciente-192 a la hora 0.00.
# Llega el paciente: Paciente-193 a la hora 0.00.
# Llega el paciente: Paciente-194 a la hora 0.00.
# Llega el paciente: Paciente-195 a la hora 0.00.
# Llega el paciente: Paciente-196 a la hora 0.00.
# Llega el paciente: Paciente-197 a la hora 0.00.
# Llega el paciente: Paciente-198 a la hora 0.00.
# Llega el paciente: Paciente-199 a la hora 0.00.
# Llega el paciente: Paciente-200 a la hora 0.00.
# Llega el paciente: Paciente-201 a la hora 0.00.
# Llega el paciente: Paciente-202 a la hora 0.00.
# Llega el paciente: Paciente-203 a la hora 0.00.
# Llega el paciente: Paciente-204 a la hora 0.00.
# Llega el paciente: Paciente-205 a la hora 0.00.
# Llega el paciente: Paciente-206 a la hora 0.00.
# Llega el paciente: Paciente-207 a la hora 0.00.
# Llega el paciente: Paciente-208 a la hora 0.00.
# Llega el paciente: Paciente-209 a la hora 0.00.
# Llega el paciente: Paciente-210 a la hora 0.00.
# Llega el paciente: Paciente-211 a la hora 0.00.
# Llega el paciente: Paciente-212 a la hora 0.00.
# Llega el paciente: Paciente-213 a la hora 0.00.
# Llega el paciente: Paciente-214 a la hora 0.00.
# Llega el paciente: Paciente-215 a la hora 0.00.
# Llega el paciente: Paciente-216 a la hora 0.00.
# Llega el paciente: Paciente-217 a la hora 0.00.
# Llega el paciente: Paciente-218 a la hora 0.00.
# Llega el paciente: Paciente-219 a la hora 0.00.
# Llega el paciente: Paciente-220 a la hora 0.00.
# Llega el paciente: Paciente-221 a la hora 0.00.
# Llega el paciente: Paciente-222 a la hora 0.00.
# Llega el paciente: Paciente-223 a la hora 0.00.
# Llega el paciente: Paciente-224 a la hora 0.00.
# Llega el paciente: Paciente-225 a la hora 0.00.
# Llega el paciente: Paciente-226 a la hora 0.00.
# Llega el paciente: Paciente-227 a la hora 0.00.
# Llega el paciente: Paciente-228 a la hora 0.00.
# Llega el paciente: Paciente-229 a la hora 0.00.
# Llega el paciente: Paciente-230 a la hora 0.00.
# Llega el paciente: Paciente-231 a la hora 0.00.
# Llega el paciente: Paciente-232 a la hora 0.00.
# Llega el paciente: Paciente-233 a la hora 0.00.
# Llega el paciente: Paciente-234 a la hora 0.00.
# Llega el paciente: Paciente-235 a la hora 0.00.
# Llega el paciente: Paciente-236 a la hora 0.00.
# Llega el paciente: Paciente-237 a la hora 0.00.
# Llega el paciente: Paciente-238 a la hora 0.00.
# Llega el paciente: Paciente-239 a la hora 0.00.
# Llega el paciente: Paciente-240 a la hora 0.00.
# Llega el paciente: Paciente-241 a la hora 0.00.
# Llega el paciente: Paciente-242 a la hora 0.00.
# Llega el paciente: Paciente-243 a la hora 0.00.
# Llega el paciente: Paciente-244 a la hora 0.00.
# Llega el paciente: Paciente-245 a la hora 0.00.
# Llega el paciente: Paciente-246 a la hora 0.00.
# Llega el paciente: Paciente-247 a la hora 0.00.
# Llega el paciente: Paciente-248 a la hora 0.00.
# Llega el paciente: Paciente-249 a la hora 0.00.
# Llega el paciente: Paciente-250 a la hora 0.00.
# Llega el paciente: Paciente-251 a la hora 0.00.
# Llega el paciente: Paciente-252 a la hora 0.00.
# Llega el paciente: Paciente-253 a la hora 0.00.
# Llega el paciente: Paciente-254 a la hora 0.00.
# Llega el paciente: Paciente-255 a la hora 0.00.
# Llega el paciente: Paciente-256 a la hora 0.00.
# Llega el paciente: Paciente-257 a la hora 0.00.
# Llega el paciente: Paciente-258 a la hora 0.00.
# Llega el paciente: Paciente-259 a la hora 0.00.
# Llega el paciente: Paciente-260 a la hora 0.00.
# Llega el paciente: Paciente-261 a la hora 0.00.
# Llega el paciente: Paciente-262 a la hora 0.00.
# Llega el paciente: Paciente-263 a la hora 0.00.
# Llega el paciente: Paciente-264 a la hora 0.00.
# Llega el paciente: Paciente-265 a la hora 0.00.
# Llega el paciente: Paciente-266 a la hora 0.00.
# Llega el paciente: Paciente-267 a la hora 0.00.
# Llega el paciente: Paciente-268 a la hora 0.00.
# Llega el paciente: Paciente-269 a la hora 0.00.
# Llega el paciente: Paciente-270 a la hora 0.00.
# Llega el paciente: Paciente-271 a la hora 0.00.
# Llega el paciente: Paciente-272 a la hora 0.00.
# Llega el paciente: Paciente-273 a la hora 0.00.
# Llega el paciente: Paciente-274 a la hora 0.00.
# Llega el paciente: Paciente-275 a la hora 0.00.
# Llega el paciente: Paciente-276 a la hora 0.00.
# Llega el paciente: Paciente-277 a la hora 0.00.
# Llega el paciente: Paciente-278 a la hora 0.00.
# Llega el paciente: Paciente-279 a la hora 0.00.
# Llega el paciente: Paciente-280 a la hora 0.00.
# Llega el paciente: Paciente-281 a la hora 0.00.
# Llega el paciente: Paciente-282 a la hora 0.00.
# Llega el paciente: Paciente-283 a la hora 0.00.
# Llega el paciente: Paciente-284 a la hora 0.00.
# Llega el paciente: Paciente-285 a la hora 0.00.
# Llega el paciente: Paciente-286 a la hora 0.00.
# Llega el paciente: Paciente-287 a la hora 0.00.
# Llega el paciente: Paciente-288 a la hora 0.00.
# Llega el paciente: Paciente-289 a la hora 0.00.
# Llega el paciente: Paciente-290 a la hora 0.00.
# Llega el paciente: Paciente-291 a la hora 0.00.
# Llega el paciente: Paciente-292 a la hora 0.00.
# Llega el paciente: Paciente-293 a la hora 0.00.
# Llega el paciente: Paciente-294 a la hora 0.00.
# Llega el paciente: Paciente-295 a la hora 0.00.
# Llega el paciente: Paciente-296 a la hora 0.00.
# Llega el paciente: Paciente-297 a la hora 0.00.
# Llega el paciente: Paciente-298 a la hora 0.00.
# Llega el paciente: Paciente-299 a la hora 0.00.
# Llega el paciente: Paciente-300 a la hora 0.00.
# Llega el paciente: Paciente-301 a la hora 0.00.
# Llega el paciente: Paciente-302 a la hora 0.00.
# Llega el paciente: Paciente-303 a la hora 0.00.
# Llega el paciente: Paciente-304 a la hora 0.00.
# Llega el paciente: Paciente-305 a la hora 0.00.
# Llega el paciente: Paciente-306 a la hora 0.00.
# Llega el paciente: Paciente-307 a la hora 0.00.
# Llega el paciente: Paciente-308 a la hora 0.00.
# Llega el paciente: Paciente-309 a la hora 0.00.
# Llega el paciente: Paciente-310 a la hora 0.00.
# Llega el paciente: Paciente-311 a la hora 0.00.
# Llega el paciente: Paciente-312 a la hora 0.00.
# Llega el paciente: Paciente-313 a la hora 0.00.
# Llega el paciente: Paciente-314 a la hora 0.00.
# Llega el paciente: Paciente-315 a la hora 0.00.
# Llega el paciente: Paciente-316 a la hora 0.00.
# Llega el paciente: Paciente-317 a la hora 0.00.
# Llega el paciente: Paciente-318 a la hora 0.00.
# Llega el paciente: Paciente-319 a la hora 0.00.
# Llega el paciente: Paciente-320 a la hora 0.00.
# Llega el paciente: Paciente-321 a la hora 0.00.
# Llega el paciente: Paciente-322 a la hora 0.00.
# Llega el paciente: Paciente-323 a la hora 0.00.
# Llega el paciente: Paciente-324 a la hora 0.00.
# Llega el paciente: Paciente-325 a la hora 0.00.
# Llega el paciente: Paciente-326 a la hora 0.00.
# Llega el paciente: Paciente-327 a la hora 0.00.
# Llega el paciente: Paciente-328 a la hora 0.00.
# Llega el paciente: Paciente-329 a la hora 0.00.
# Llega el paciente: Paciente-330 a la hora 0.00.
# Llega el paciente: Paciente-331 a la hora 0.00.
# Llega el paciente: Paciente-332 a la hora 0.00.
# Llega el paciente: Paciente-333 a la hora 0.00.
# Llega el paciente: Paciente-334 a la hora 0.00.
# Llega el paciente: Paciente-335 a la hora 0.00.
# Llega el paciente: Paciente-336 a la hora 0.00.
# Llega el paciente: Paciente-337 a la hora 0.00.
# Llega el paciente: Paciente-338 a la hora 0.00.
# Llega el paciente: Paciente-339 a la hora 0.00.
# Llega el paciente: Paciente-340 a la hora 0.00.
# Llega el paciente: Paciente-341 a la hora 0.00.
# Llega el paciente: Paciente-342 a la hora 0.00.
# Llega el paciente: Paciente-343 a la hora 0.00.
# Llega el paciente: Paciente-344 a la hora 0.00.
# Llega el paciente: Paciente-345 a la hora 0.00.
# Llega el paciente: Paciente-346 a la hora 0.00.
# Llega el paciente: Paciente-347 a la hora 0.00.
# Llega el paciente: Paciente-348 a la hora 0.00.
# Llega el paciente: Paciente-349 a la hora 0.00.
# Llega el paciente: Paciente-350 a la hora 0.00.
# Llega el paciente: Paciente-351 a la hora 0.00.
# Llega el paciente: Paciente-352 a la hora 0.00.
# Llega el paciente: Paciente-353 a la hora 0.00.
# Llega el paciente: Paciente-354 a la hora 0.00.
# Llega el paciente: Paciente-355 a la hora 0.00.
# Llega el paciente: Paciente-356 a la hora 0.00.
# Llega el paciente: Paciente-357 a la hora 0.00.
# Llega el paciente: Paciente-358 a la hora 0.00.
# Llega el paciente: Paciente-359 a la hora 0.00.
# Llega el paciente: Paciente-360 a la hora 0.00.
# Llega el paciente: Paciente-361 a la hora 0.00.
# Llega el paciente: Paciente-362 a la hora 0.00.
# Llega el paciente: Paciente-363 a la hora 0.00.
# Llega el paciente: Paciente-364 a la hora 0.00.
# Llega el paciente: Paciente-365 a la hora 0.00.
# Llega el paciente: Paciente-366 a la hora 0.00.
# Llega el paciente: Paciente-367 a la hora 0.00.
# Llega el paciente: Paciente-368 a la hora 0.00.
# Llega el paciente: Paciente-369 a la hora 0.00.
# Llega el paciente: Paciente-370 a la hora 0.00.
# Llega el paciente: Paciente-371 a la hora 0.00.
# Llega el paciente: Paciente-372 a la hora 0.00.
# Llega el paciente: Paciente-373 a la hora 0.00.
# Llega el paciente: Paciente-374 a la hora 0.00.
# Llega el paciente: Paciente-375 a la hora 0.00.
# Llega el paciente: Paciente-376 a la hora 0.00.
# Llega el paciente: Paciente-377 a la hora 0.00.
# Llega el paciente: Paciente-378 a la hora 0.00.
# Llega el paciente: Paciente-379 a la hora 0.00.
# Llega el paciente: Paciente-380 a la hora 0.00.
# Llega el paciente: Paciente-381 a la hora 0.00.
# Llega el paciente: Paciente-382 a la hora 0.00.
# Llega el paciente: Paciente-383 a la hora 0.00.
# Llega el paciente: Paciente-384 a la hora 0.00.
# Llega el paciente: Paciente-385 a la hora 0.00.
# Llega el paciente: Paciente-386 a la hora 0.00.
# Llega el paciente: Paciente-387 a la hora 0.00.
# Llega el paciente: Paciente-388 a la hora 0.00.
# Llega el paciente: Paciente-389 a la hora 0.00.
# Llega el paciente: Paciente-390 a la hora 0.00.
# Llega el paciente: Paciente-391 a la hora 0.00.
# Llega el paciente: Paciente-392 a la hora 0.00.
# Llega el paciente: Paciente-393 a la hora 0.00.
# Llega el paciente: Paciente-394 a la hora 0.00.
# Llega el paciente: Paciente-395 a la hora 0.00.
# Llega el paciente: Paciente-396 a la hora 0.00.
# Llega el paciente: Paciente-397 a la hora 0.00.
# Llega el paciente: Paciente-398 a la hora 0.00.
# Llega el paciente: Paciente-399 a la hora 0.00.
# Llega el paciente: Paciente-400 a la hora 0.00.
# Se traslada el paciente: Paciente-1 a la hora 0.00.
# Se traslada el paciente: Paciente-2 a la hora 0.00.
# Se traslada el paciente: Paciente-3 a la hora 0.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-3 a la hora 3.00.
# Tiempo tomado:  8  para paciente:  Paciente-3
# Sintomas:  2
# Ingresa el paciente a las Paciente-2 a la hora 5.00.
# Tiempo tomado:  9  para paciente:  Paciente-2
# Paciente [Paciente-1] trasladado a la salida a las 6.00.
# Se traslada el paciente: Paciente-4 a la hora 6.00.
# Llega el paciente: Paciente-401 a la hora 10.00.
# Paciente  3
# Paciente [Paciente-3] vacunado a las 11.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-4 a la hora 11.00.
# Tiempo tomado:  6  para paciente:  Paciente-4
# Paciente  2
# Paciente [Paciente-2] vacunado a las 14.00.
# Paciente [Paciente-3] trasladado a la salida a las 14.00.
# Se traslada el paciente: Paciente-5 a la hora 14.00.
# Paciente  4
# Paciente [Paciente-4] vacunado a las 17.00.
# Paciente [Paciente-2] trasladado a la salida a las 17.00.
# Se traslada el paciente: Paciente-6 a la hora 17.00.
# Sintomas:  1
# Paciente [Paciente-4] trasladado a la salida a las 18.00.
# Se traslada el paciente: Paciente-7 a la hora 18.00.
# Paciente [Paciente-5] trasladado a la salida a las 19.00.
# Se traslada el paciente: Paciente-8 a la hora 19.00.
# Llega el paciente: Paciente-402 a la hora 21.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-6 a la hora 22.00.
# Tiempo tomado:  9  para paciente:  Paciente-6
# Sintomas:  2
# Ingresa el paciente a las Paciente-7 a la hora 23.00.
# Tiempo tomado:  8  para paciente:  Paciente-7
# Sintomas:  1
# Paciente [Paciente-8] trasladado a la salida a las 24.00.
# Se traslada el paciente: Paciente-9 a la hora 24.00.
# Sintomas:  1
# Llega el paciente: Paciente-403 a la hora 27.00.
# Paciente [Paciente-9] trasladado a la salida a las 29.00.
# Se traslada el paciente: Paciente-10 a la hora 29.00.
# Paciente  6
# Paciente  7
# Paciente [Paciente-6] vacunado a las 31.00.
# Paciente [Paciente-7] vacunado a las 31.00.
# Llega el paciente: Paciente-404 a la hora 32.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-10 a la hora 32.00.
# Tiempo tomado:  5  para paciente:  Paciente-10
# Paciente [Paciente-6] trasladado a la salida a las 32.00.
# Paciente [Paciente-7] trasladado a la salida a las 32.00.
# Se traslada el paciente: Paciente-11 a la hora 32.00.
# Se traslada el paciente: Paciente-12 a la hora 32.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-12 a la hora 36.00.
# Tiempo tomado:  9  para paciente:  Paciente-12
# Paciente  10
# Paciente [Paciente-10] vacunado a las 37.00.
# Llega el paciente: Paciente-405 a la hora 38.00.
# Paciente [Paciente-11] trasladado a la salida a las 38.00.
# Se traslada el paciente: Paciente-13 a la hora 38.00.
# Paciente [Paciente-10] trasladado a la salida a las 40.00.
# Sintomas:  1
# Se traslada el paciente: Paciente-14 a la hora 40.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-14 a la hora 42.00.
# Tiempo tomado:  6  para paciente:  Paciente-14
# Llega el paciente: Paciente-406 a la hora 43.00.
# Paciente [Paciente-13] trasladado a la salida a las 43.00.
# Se traslada el paciente: Paciente-15 a la hora 43.00.
# Paciente  12
# Paciente [Paciente-12] vacunado a las 45.00.
# Sintomas:  1
# Paciente [Paciente-15] trasladado a la salida a las 46.00.
# Se traslada el paciente: Paciente-16 a la hora 46.00.
# Paciente  14
# Paciente [Paciente-14] vacunado a las 48.00.
# Paciente [Paciente-12] trasladado a la salida a las 48.00.
# Se traslada el paciente: Paciente-17 a la hora 48.00.
# Paciente [Paciente-14] trasladado a la salida a las 50.00.
# Se traslada el paciente: Paciente-18 a la hora 50.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-16 a la hora 51.00.
# Tiempo tomado:  9  para paciente:  Paciente-16
# Sintomas:  2
# Ingresa el paciente a las Paciente-17 a la hora 52.00.
# Tiempo tomado:  7  para paciente:  Paciente-17
# Sintomas:  1
# Paciente [Paciente-18] trasladado a la salida a las 57.00.
# Se traslada el paciente: Paciente-19 a la hora 57.00.
# Paciente  17
# Paciente [Paciente-17] vacunado a las 59.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-19 a la hora 59.00.
# Tiempo tomado:  6  para paciente:  Paciente-19
# Llega el paciente: Paciente-407 a la hora 60.00.
# Paciente  16
# Paciente [Paciente-16] vacunado a las 60.00.
# Paciente [Paciente-17] trasladado a la salida a las 61.00.
# Se traslada el paciente: Paciente-20 a la hora 61.00.
# Paciente [Paciente-16] trasladado a la salida a las 63.00.
# Sintomas:  1
# Se traslada el paciente: Paciente-21 a la hora 63.00.
# Paciente [Paciente-20] trasladado a la salida a las 64.00.
# Se traslada el paciente: Paciente-22 a la hora 64.00.
# Paciente  19
# Paciente [Paciente-19] vacunado a las 65.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-21 a la hora 67.00.
# Tiempo tomado:  10  para paciente:  Paciente-21
# Paciente [Paciente-19] trasladado a la salida a las 68.00.
# Se traslada el paciente: Paciente-23 a la hora 68.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-22 a la hora 69.00.
# Tiempo tomado:  10  para paciente:  Paciente-22
# Sintomas:  2
# Ingresa el paciente a las Paciente-23 a la hora 70.00.
# Tiempo tomado:  5  para paciente:  Paciente-23
# Llega el paciente: Paciente-408 a la hora 75.00.
# Paciente  23
# Paciente [Paciente-23] vacunado a las 75.00.
# Paciente  21
# Paciente [Paciente-21] vacunado a las 77.00.
# Paciente [Paciente-23] trasladado a la salida a las 77.00.
# Se traslada el paciente: Paciente-24 a la hora 77.00.
# Paciente  22
# Paciente [Paciente-22] vacunado a las 79.00.
# Paciente [Paciente-21] trasladado a la salida a las 80.00.
# Se traslada el paciente: Paciente-25 a la hora 80.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-24 a la hora 81.00.
# Tiempo tomado:  8  para paciente:  Paciente-24
# Paciente [Paciente-22] trasladado a la salida a las 81.00.
# Se traslada el paciente: Paciente-26 a la hora 81.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-25 a la hora 82.00.
# Tiempo tomado:  6  para paciente:  Paciente-25
# Sintomas:  1
# Paciente [Paciente-26] trasladado a la salida a las 86.00.
# Se traslada el paciente: Paciente-27 a la hora 86.00.
# Llega el paciente: Paciente-409 a la hora 88.00.
# Paciente  25
# Paciente [Paciente-25] vacunado a las 88.00.
# Paciente  24
# Paciente [Paciente-24] vacunado a las 89.00.
# Paciente [Paciente-25] trasladado a la salida a las 89.00.
# Se traslada el paciente: Paciente-28 a la hora 89.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-27 a la hora 90.00.
# Tiempo tomado:  8  para paciente:  Paciente-27
# Paciente [Paciente-24] trasladado a la salida a las 92.00.
# Se traslada el paciente: Paciente-29 a la hora 92.00.
# Sintomas:  1
# Paciente [Paciente-28] trasladado a la salida a las 94.00.
# Se traslada el paciente: Paciente-30 a la hora 94.00.
# Sintomas:  1
# Paciente [Paciente-29] trasladado a la salida a las 96.00.
# Se traslada el paciente: Paciente-31 a la hora 96.00.
# Paciente  27
# Paciente [Paciente-27] vacunado a las 98.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-30 a la hora 98.00.
# Tiempo tomado:  7  para paciente:  Paciente-30
# Paciente [Paciente-27] trasladado a la salida a las 99.00.
# Se traslada el paciente: Paciente-32 a la hora 99.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-31 a la hora 101.00.
# Tiempo tomado:  9  para paciente:  Paciente-31
# Sintomas:  1
# Paciente [Paciente-32] trasladado a la salida a las 102.00.
# Se traslada el paciente: Paciente-33 a la hora 102.00.
# Llega el paciente: Paciente-410 a la hora 104.00.
# Sintomas:  1
# Paciente  30
# Paciente [Paciente-30] vacunado a las 105.00.
# Paciente [Paciente-33] trasladado a la salida a las 105.00.
# Se traslada el paciente: Paciente-34 a la hora 105.00.
# Paciente [Paciente-30] trasladado a la salida a las 106.00.
# Se traslada el paciente: Paciente-35 a la hora 106.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-34 a la hora 108.00.
# Tiempo tomado:  7  para paciente:  Paciente-34
# Llega el paciente: Paciente-411 a la hora 109.00.
# Paciente  31
# Paciente [Paciente-31] vacunado a las 110.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-35 a la hora 110.00.
# Tiempo tomado:  7  para paciente:  Paciente-35
# Llega el paciente: Paciente-412 a la hora 112.00.
# Paciente [Paciente-31] trasladado a la salida a las 112.00.
# Se traslada el paciente: Paciente-36 a la hora 112.00.
# Paciente  34
# Paciente [Paciente-34] vacunado a las 115.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-36 a la hora 115.00.
# Tiempo tomado:  8  para paciente:  Paciente-36
# Paciente  35
# Paciente [Paciente-35] vacunado a las 117.00.
# Paciente [Paciente-34] trasladado a la salida a las 118.00.
# Se traslada el paciente: Paciente-37 a la hora 118.00.
# Paciente [Paciente-35] trasladado a la salida a las 119.00.
# Se traslada el paciente: Paciente-38 a la hora 119.00.
# Sintomas:  1
# Paciente  36
# Paciente [Paciente-36] vacunado a las 123.00.
# Sintomas:  1
# Paciente [Paciente-37] trasladado a la salida a las 125.00.
# Paciente [Paciente-36] trasladado a la salida a las 125.00.
# Se traslada el paciente: Paciente-39 a la hora 125.00.
# Se traslada el paciente: Paciente-40 a la hora 125.00.
# Llega el paciente: Paciente-413 a la hora 127.00.
# Paciente [Paciente-38] trasladado a la salida a las 127.00.
# Se traslada el paciente: Paciente-41 a la hora 127.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-39 a la hora 128.00.
# Tiempo tomado:  8  para paciente:  Paciente-39
# Sintomas:  2
# Ingresa el paciente a las Paciente-40 a la hora 130.00.
# Tiempo tomado:  5  para paciente:  Paciente-40
# Sintomas:  2
# Ingresa el paciente a las Paciente-41 a la hora 130.00.
# Tiempo tomado:  8  para paciente:  Paciente-41
# Paciente  40
# Paciente [Paciente-40] vacunado a las 135.00.
# Paciente  39
# Paciente [Paciente-39] vacunado a las 136.00.
# Llega el paciente: Paciente-414 a la hora 137.00.
# Paciente [Paciente-40] trasladado a la salida a las 137.00.
# Se traslada el paciente: Paciente-42 a la hora 137.00.
# Paciente  41
# Paciente [Paciente-41] vacunado a las 138.00.
# Paciente [Paciente-39] trasladado a la salida a las 139.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-42 a la hora 139.00.
# Tiempo tomado:  6  para paciente:  Paciente-42
# Paciente [Paciente-41] trasladado a la salida a las 139.00.
# Se traslada el paciente: Paciente-43 a la hora 139.00.
# Se traslada el paciente: Paciente-44 a la hora 139.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-43 a la hora 144.00.
# Tiempo tomado:  9  para paciente:  Paciente-43
# Paciente [Paciente-44] trasladado a la salida a las 144.00.
# Se traslada el paciente: Paciente-45 a la hora 144.00.
# Paciente  42
# Paciente [Paciente-42] vacunado a las 145.00.
# Paciente [Paciente-42] trasladado a la salida a las 146.00.
# Se traslada el paciente: Paciente-46 a la hora 146.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-45] trasladado a la salida a las 151.00.
# Paciente [Paciente-46] trasladado a la salida a las 151.00.
# Se traslada el paciente: Paciente-47 a la hora 151.00.
# Se traslada el paciente: Paciente-48 a la hora 151.00.
# Paciente  43
# Paciente [Paciente-43] vacunado a las 153.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-48 a la hora 155.00.
# Tiempo tomado:  10  para paciente:  Paciente-48
# Paciente [Paciente-43] trasladado a la salida a las 155.00.
# Se traslada el paciente: Paciente-49 a la hora 155.00.
# Llega el paciente: Paciente-415 a la hora 157.00.
# Paciente [Paciente-47] trasladado a la salida a las 157.00.
# Se traslada el paciente: Paciente-50 a la hora 157.00.
# Sintomas:  1
# Paciente [Paciente-49] trasladado a la salida a las 160.00.
# Se traslada el paciente: Paciente-51 a la hora 160.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-50 a la hora 161.00.
# Tiempo tomado:  5  para paciente:  Paciente-50
# Sintomas:  2
# Ingresa el paciente a las Paciente-51 a la hora 163.00.
# Tiempo tomado:  8  para paciente:  Paciente-51
# Paciente  48
# Paciente [Paciente-48] vacunado a las 165.00.
# Paciente  50
# Paciente [Paciente-50] vacunado a las 166.00.
# Paciente [Paciente-48] trasladado a la salida a las 167.00.
# Paciente [Paciente-50] trasladado a la salida a las 167.00.
# Se traslada el paciente: Paciente-52 a la hora 167.00.
# Se traslada el paciente: Paciente-53 a la hora 167.00.
# Sintomas:  1
# Sintomas:  1
# Paciente  51
# Paciente [Paciente-51] vacunado a las 171.00.
# Paciente [Paciente-53] trasladado a la salida a las 172.00.
# Paciente [Paciente-51] trasladado a la salida a las 172.00.
# Se traslada el paciente: Paciente-54 a la hora 172.00.
# Se traslada el paciente: Paciente-55 a la hora 172.00.
# Llega el paciente: Paciente-416 a la hora 173.00.
# Paciente [Paciente-52] trasladado a la salida a las 173.00.
# Se traslada el paciente: Paciente-56 a la hora 173.00.
# Sintomas:  1
# Llega el paciente: Paciente-417 a la hora 176.00.
# Sintomas:  1
# Paciente [Paciente-54] trasladado a la salida a las 176.00.
# Se traslada el paciente: Paciente-57 a la hora 176.00.
# Paciente [Paciente-55] trasladado a la salida a las 177.00.
# Se traslada el paciente: Paciente-58 a la hora 177.00.
# Sintomas:  1
# Llega el paciente: Paciente-418 a la hora 179.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-57 a la hora 179.00.
# Tiempo tomado:  5  para paciente:  Paciente-57
# Paciente [Paciente-56] trasladado a la salida a las 179.00.
# Se traslada el paciente: Paciente-59 a la hora 179.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-58 a la hora 180.00.
# Tiempo tomado:  9  para paciente:  Paciente-58
# Sintomas:  1
# Llega el paciente: Paciente-419 a la hora 183.00.
# Paciente  57
# Paciente [Paciente-57] vacunado a las 184.00.
# Paciente [Paciente-59] trasladado a la salida a las 184.00.
# Se traslada el paciente: Paciente-60 a la hora 184.00.
# Paciente [Paciente-57] trasladado a la salida a las 186.00.
# Se traslada el paciente: Paciente-61 a la hora 186.00.
# Paciente  58
# Paciente [Paciente-58] vacunado a las 189.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-60 a la hora 189.00.
# Tiempo tomado:  7  para paciente:  Paciente-60
# Sintomas:  1
# Paciente [Paciente-58] trasladado a la salida a las 192.00.
# Se traslada el paciente: Paciente-62 a la hora 192.00.
# Paciente [Paciente-61] trasladado a la salida a las 194.00.
# Se traslada el paciente: Paciente-63 a la hora 194.00.
# Llega el paciente: Paciente-420 a la hora 195.00.
# Paciente  60
# Paciente [Paciente-60] vacunado a las 196.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-62 a la hora 196.00.
# Tiempo tomado:  8  para paciente:  Paciente-62
# Sintomas:  1
# Paciente [Paciente-60] trasladado a la salida a las 199.00.
# Se traslada el paciente: Paciente-64 a la hora 199.00.
# Paciente [Paciente-63] trasladado a la salida a las 202.00.
# Se traslada el paciente: Paciente-65 a la hora 202.00.
# Paciente  62
# Paciente [Paciente-62] vacunado a las 204.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-64 a la hora 204.00.
# Tiempo tomado:  6  para paciente:  Paciente-64
# Sintomas:  1
# Paciente [Paciente-62] trasladado a la salida a las 206.00.
# Paciente [Paciente-65] trasladado a la salida a las 206.00.
# Se traslada el paciente: Paciente-66 a la hora 206.00.
# Se traslada el paciente: Paciente-67 a la hora 206.00.
# Paciente  64
# Paciente [Paciente-64] vacunado a las 210.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-66] trasladado a la salida a las 212.00.
# Se traslada el paciente: Paciente-68 a la hora 212.00.
# Paciente [Paciente-64] trasladado a la salida a las 213.00.
# Se traslada el paciente: Paciente-69 a la hora 213.00.
# Llega el paciente: Paciente-421 a la hora 214.00.
# Llega el paciente: Paciente-422 a la hora 214.00.
# Paciente [Paciente-67] trasladado a la salida a las 214.00.
# Se traslada el paciente: Paciente-70 a la hora 214.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-68 a la hora 217.00.
# Tiempo tomado:  8  para paciente:  Paciente-68
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-69] trasladado a la salida a las 221.00.
# Se traslada el paciente: Paciente-71 a la hora 221.00.
# Paciente [Paciente-70] trasladado a la salida a las 222.00.
# Se traslada el paciente: Paciente-72 a la hora 222.00.
# Paciente  68
# Paciente [Paciente-68] vacunado a las 225.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-68] trasladado a la salida a las 226.00.
# Se traslada el paciente: Paciente-73 a la hora 226.00.
# Paciente [Paciente-72] trasladado a la salida a las 228.00.
# Paciente [Paciente-71] trasladado a la salida a las 228.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-73 a la hora 228.00.
# Tiempo tomado:  9  para paciente:  Paciente-73
# Se traslada el paciente: Paciente-74 a la hora 228.00.
# Se traslada el paciente: Paciente-75 a la hora 228.00.
# Llega el paciente: Paciente-423 a la hora 229.00.
# Sintomas:  1
# Paciente [Paciente-75] trasladado a la salida a las 232.00.
# Se traslada el paciente: Paciente-76 a la hora 232.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-76 a la hora 235.00.
# Tiempo tomado:  9  para paciente:  Paciente-76
# Paciente [Paciente-74] trasladado a la salida a las 236.00.
# Se traslada el paciente: Paciente-77 a la hora 236.00.
# Paciente  73
# Paciente [Paciente-73] vacunado a las 237.00.
# Paciente [Paciente-73] trasladado a la salida a las 239.00.
# Se traslada el paciente: Paciente-78 a la hora 239.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-77 a la hora 241.00.
# Tiempo tomado:  5  para paciente:  Paciente-77
# Sintomas:  1
# Paciente  76
# Paciente [Paciente-76] vacunado a las 244.00.
# Paciente [Paciente-78] trasladado a la salida a las 244.00.
# Se traslada el paciente: Paciente-79 a la hora 244.00.
# Paciente  77
# Paciente [Paciente-77] vacunado a las 246.00.
# Paciente [Paciente-76] trasladado a la salida a las 246.00.
# Se traslada el paciente: Paciente-80 a la hora 246.00.
# Paciente [Paciente-77] trasladado a la salida a las 247.00.
# Se traslada el paciente: Paciente-81 a la hora 247.00.
# Sintomas:  1
# Llega el paciente: Paciente-424 a la hora 249.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-80 a la hora 249.00.
# Tiempo tomado:  5  para paciente:  Paciente-80
# Paciente [Paciente-79] trasladado a la salida a las 249.00.
# Se traslada el paciente: Paciente-82 a la hora 249.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-81 a la hora 251.00.
# Tiempo tomado:  8  para paciente:  Paciente-81
# Sintomas:  2
# Ingresa el paciente a las Paciente-82 a la hora 251.00.
# Tiempo tomado:  5  para paciente:  Paciente-82
# Paciente  80
# Paciente [Paciente-80] vacunado a las 254.00.
# Paciente  82
# Paciente [Paciente-82] vacunado a las 256.00.
# Paciente [Paciente-80] trasladado a la salida a las 256.00.
# Se traslada el paciente: Paciente-83 a la hora 256.00.
# Llega el paciente: Paciente-425 a la hora 257.00.
# Paciente  81
# Paciente [Paciente-81] vacunado a las 259.00.
# Paciente [Paciente-82] trasladado a la salida a las 259.00.
# Se traslada el paciente: Paciente-84 a la hora 259.00.
# Llega el paciente: Paciente-426 a la hora 260.00.
# Sintomas:  1
# Paciente [Paciente-81] trasladado a la salida a las 260.00.
# Se traslada el paciente: Paciente-85 a la hora 260.00.
# Sintomas:  1
# Paciente [Paciente-83] trasladado a la salida a las 263.00.
# Se traslada el paciente: Paciente-86 a la hora 263.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-85 a la hora 264.00.
# Tiempo tomado:  8  para paciente:  Paciente-85
# Paciente [Paciente-84] trasladado a la salida a las 264.00.
# Se traslada el paciente: Paciente-87 a la hora 264.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-86 a la hora 266.00.
# Tiempo tomado:  10  para paciente:  Paciente-86
# Sintomas:  2
# Ingresa el paciente a las Paciente-87 a la hora 266.00.
# Tiempo tomado:  5  para paciente:  Paciente-87
# Paciente  87
# Paciente [Paciente-87] vacunado a las 271.00.
# Paciente  85
# Paciente [Paciente-85] vacunado a las 272.00.
# Paciente [Paciente-87] trasladado a la salida a las 272.00.
# Se traslada el paciente: Paciente-88 a la hora 272.00.
# Paciente [Paciente-85] trasladado a la salida a las 273.00.
# Se traslada el paciente: Paciente-89 a la hora 273.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-88 a la hora 275.00.
# Tiempo tomado:  6  para paciente:  Paciente-88
# Paciente  86
# Paciente [Paciente-86] vacunado a las 276.00.
# Llega el paciente: Paciente-427 a la hora 278.00.
# Llega el paciente: Paciente-428 a la hora 278.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-89 a la hora 278.00.
# Tiempo tomado:  5  para paciente:  Paciente-89
# Paciente [Paciente-86] trasladado a la salida a las 278.00.
# Se traslada el paciente: Paciente-90 a la hora 278.00.
# Paciente  88
# Paciente [Paciente-88] vacunado a las 281.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-90 a la hora 281.00.
# Tiempo tomado:  6  para paciente:  Paciente-90
# Paciente  89
# Paciente [Paciente-89] vacunado a las 283.00.
# Paciente [Paciente-88] trasladado a la salida a las 284.00.
# Se traslada el paciente: Paciente-91 a la hora 284.00.
# Paciente [Paciente-89] trasladado a la salida a las 286.00.
# Se traslada el paciente: Paciente-92 a la hora 286.00.
# Paciente  90
# Paciente [Paciente-90] vacunado a las 287.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-91 a la hora 289.00.
# Tiempo tomado:  9  para paciente:  Paciente-91
# Paciente [Paciente-90] trasladado a la salida a las 289.00.
# Se traslada el paciente: Paciente-93 a la hora 289.00.
# Paciente [Paciente-92] trasladado a la salida a las 290.00.
# Se traslada el paciente: Paciente-94 a la hora 290.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-93] trasladado a la salida a las 293.00.
# Se traslada el paciente: Paciente-95 a la hora 293.00.
# Paciente [Paciente-94] trasladado a la salida a las 294.00.
# Se traslada el paciente: Paciente-96 a la hora 294.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-95 a la hora 296.00.
# Tiempo tomado:  6  para paciente:  Paciente-95
# Sintomas:  2
# Ingresa el paciente a las Paciente-96 a la hora 297.00.
# Tiempo tomado:  9  para paciente:  Paciente-96
# Llega el paciente: Paciente-429 a la hora 298.00.
# Paciente  91
# Paciente [Paciente-91] vacunado a las 298.00.
# Paciente [Paciente-91] trasladado a la salida a las 301.00.
# Se traslada el paciente: Paciente-97 a la hora 301.00.
# Paciente  95
# Paciente [Paciente-95] vacunado a las 302.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-97 a la hora 305.00.
# Tiempo tomado:  5  para paciente:  Paciente-97
# Paciente [Paciente-95] trasladado a la salida a las 305.00.
# Se traslada el paciente: Paciente-98 a la hora 305.00.
# Paciente  96
# Paciente [Paciente-96] vacunado a las 306.00.
# Paciente [Paciente-96] trasladado a la salida a las 309.00.
# Se traslada el paciente: Paciente-99 a la hora 309.00.
# Paciente  97
# Paciente [Paciente-97] vacunado a las 310.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-98 a la hora 310.00.
# Tiempo tomado:  5  para paciente:  Paciente-98
# Sintomas:  1
# Paciente [Paciente-97] trasladado a la salida a las 313.00.
# Se traslada el paciente: Paciente-100 a la hora 313.00.
# Llega el paciente: Paciente-430 a la hora 314.00.
# Paciente  98
# Llega el paciente: Paciente-431 a la hora 315.00.
# Paciente [Paciente-98] vacunado a las 315.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-100 a la hora 315.00.
# Tiempo tomado:  9  para paciente:  Paciente-100
# Paciente [Paciente-99] trasladado a la salida a las 316.00.
# Se traslada el paciente: Paciente-101 a la hora 316.00.
# Paciente [Paciente-98] trasladado a la salida a las 318.00.
# Se traslada el paciente: Paciente-102 a la hora 318.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-102 a la hora 320.00.
# Tiempo tomado:  9  para paciente:  Paciente-102
# Paciente [Paciente-101] trasladado a la salida a las 321.00.
# Se traslada el paciente: Paciente-103 a la hora 321.00.
# Paciente  100
# Paciente [Paciente-100] vacunado a las 324.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-103 a la hora 325.00.
# Tiempo tomado:  7  para paciente:  Paciente-103
# Llega el paciente: Paciente-432 a la hora 326.00.
# Paciente [Paciente-100] trasladado a la salida a las 326.00.
# Se traslada el paciente: Paciente-104 a la hora 326.00.
# Paciente  102
# Paciente [Paciente-102] vacunado a las 329.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-104 a la hora 329.00.
# Tiempo tomado:  5  para paciente:  Paciente-104
# Paciente [Paciente-102] trasladado a la salida a las 331.00.
# Se traslada el paciente: Paciente-105 a la hora 331.00.
# Paciente  103
# Paciente [Paciente-103] vacunado a las 332.00.
# Paciente  104
# Paciente [Paciente-104] vacunado a las 334.00.
# Paciente [Paciente-103] trasladado a la salida a las 334.00.
# Se traslada el paciente: Paciente-106 a la hora 334.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-105 a la hora 335.00.
# Tiempo tomado:  8  para paciente:  Paciente-105
# Paciente [Paciente-104] trasladado a la salida a las 335.00.
# Se traslada el paciente: Paciente-107 a la hora 335.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-106] trasladado a la salida a las 338.00.
# Paciente [Paciente-107] trasladado a la salida a las 338.00.
# Se traslada el paciente: Paciente-108 a la hora 338.00.
# Se traslada el paciente: Paciente-109 a la hora 338.00.
# Sintomas:  1
# Llega el paciente: Paciente-433 a la hora 343.00.
# Paciente  105
# Paciente [Paciente-105] vacunado a las 343.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-108 a la hora 343.00.
# Tiempo tomado:  7  para paciente:  Paciente-108
# Paciente [Paciente-109] trasladado a la salida a las 343.00.
# Se traslada el paciente: Paciente-110 a la hora 343.00.
# Paciente [Paciente-105] trasladado a la salida a las 344.00.
# Se traslada el paciente: Paciente-111 a la hora 344.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-110 a la hora 345.00.
# Tiempo tomado:  5  para paciente:  Paciente-110
# Llega el paciente: Paciente-434 a la hora 346.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-111 a la hora 346.00.
# Tiempo tomado:  9  para paciente:  Paciente-111
# Paciente  108
# Paciente  110
# Paciente [Paciente-108] vacunado a las 350.00.
# Paciente [Paciente-110] vacunado a las 350.00.
# Paciente [Paciente-108] trasladado a la salida a las 353.00.
# Paciente [Paciente-110] trasladado a la salida a las 353.00.
# Se traslada el paciente: Paciente-112 a la hora 353.00.
# Se traslada el paciente: Paciente-113 a la hora 353.00.
# Paciente  111
# Paciente [Paciente-111] vacunado a las 355.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-113 a la hora 355.00.
# Tiempo tomado:  10  para paciente:  Paciente-113
# Llega el paciente: Paciente-435 a la hora 356.00.
# Sintomas:  1
# Paciente [Paciente-112] trasladado a la salida a las 357.00.
# Se traslada el paciente: Paciente-114 a la hora 357.00.
# Paciente [Paciente-111] trasladado a la salida a las 358.00.
# Se traslada el paciente: Paciente-115 a la hora 358.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-115] trasladado a la salida a las 363.00.
# Se traslada el paciente: Paciente-116 a la hora 363.00.
# Paciente [Paciente-114] trasladado a la salida a las 364.00.
# Se traslada el paciente: Paciente-117 a la hora 364.00.
# Paciente  113
# Paciente [Paciente-113] vacunado a las 365.00.
# Paciente [Paciente-113] trasladado a la salida a las 366.00.
# Se traslada el paciente: Paciente-118 a la hora 366.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-117 a la hora 367.00.
# Tiempo tomado:  9  para paciente:  Paciente-117
# Sintomas:  2
# Ingresa el paciente a las Paciente-116 a la hora 368.00.
# Tiempo tomado:  8  para paciente:  Paciente-116
# Sintomas:  2
# Ingresa el paciente a las Paciente-118 a la hora 371.00.
# Tiempo tomado:  8  para paciente:  Paciente-118
# Llega el paciente: Paciente-436 a la hora 376.00.
# Paciente  117
# Paciente  116
# Paciente [Paciente-117] vacunado a las 376.00.
# Paciente [Paciente-116] vacunado a las 376.00.
# Paciente [Paciente-116] trasladado a la salida a las 377.00.
# Se traslada el paciente: Paciente-119 a la hora 377.00.
# Paciente  118
# Paciente [Paciente-118] vacunado a las 379.00.
# Paciente [Paciente-117] trasladado a la salida a las 379.00.
# Se traslada el paciente: Paciente-120 a la hora 379.00.
# Llega el paciente: Paciente-437 a la hora 381.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-119 a la hora 382.00.
# Tiempo tomado:  5  para paciente:  Paciente-119
# Paciente [Paciente-118] trasladado a la salida a las 382.00.
# Se traslada el paciente: Paciente-121 a la hora 382.00.
# Paciente [Paciente-120] trasladado a la salida a las 384.00.
# Se traslada el paciente: Paciente-122 a la hora 384.00.
# Llega el paciente: Paciente-438 a la hora 385.00.
# Sintomas:  1
# Paciente  119
# Paciente [Paciente-119] vacunado a las 387.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-122 a la hora 387.00.
# Tiempo tomado:  5  para paciente:  Paciente-122
# Paciente [Paciente-119] trasladado a la salida a las 388.00.
# Se traslada el paciente: Paciente-123 a la hora 388.00.
# Llega el paciente: Paciente-439 a la hora 389.00.
# Paciente [Paciente-121] trasladado a la salida a las 389.00.
# Se traslada el paciente: Paciente-124 a la hora 389.00.
# Paciente  122
# Paciente [Paciente-122] vacunado a las 392.00.
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-124 a la hora 394.00.
# Tiempo tomado:  8  para paciente:  Paciente-124
# Paciente [Paciente-122] trasladado a la salida a las 394.00.
# Paciente [Paciente-123] trasladado a la salida a las 394.00.
# Se traslada el paciente: Paciente-125 a la hora 394.00.
# Se traslada el paciente: Paciente-126 a la hora 394.00.
# Llega el paciente: Paciente-440 a la hora 395.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-125] trasladado a la salida a las 398.00.
# Se traslada el paciente: Paciente-127 a la hora 398.00.
# Paciente [Paciente-126] trasladado a la salida a las 399.00.
# Se traslada el paciente: Paciente-128 a la hora 399.00.
# Paciente  124
# Paciente [Paciente-124] vacunado a las 402.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-124] trasladado a la salida a las 404.00.
# Paciente [Paciente-128] trasladado a la salida a las 404.00.
# Se traslada el paciente: Paciente-129 a la hora 404.00.
# Se traslada el paciente: Paciente-130 a la hora 404.00.
# Paciente [Paciente-127] trasladado a la salida a las 405.00.
# Se traslada el paciente: Paciente-131 a la hora 405.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-131 a la hora 407.00.
# Tiempo tomado:  6  para paciente:  Paciente-131
# Sintomas:  2
# Ingresa el paciente a las Paciente-129 a la hora 409.00.
# Tiempo tomado:  8  para paciente:  Paciente-129
# Sintomas:  1
# Paciente [Paciente-130] trasladado a la salida a las 412.00.
# Se traslada el paciente: Paciente-132 a la hora 412.00.
# Paciente  131
# Paciente [Paciente-131] vacunado a las 413.00.
# Llega el paciente: Paciente-441 a la hora 414.00.
# Paciente [Paciente-131] trasladado a la salida a las 414.00.
# Se traslada el paciente: Paciente-133 a la hora 414.00.
# Sintomas:  1
# Paciente  129
# Paciente [Paciente-129] vacunado a las 417.00.
# Paciente [Paciente-132] trasladado a la salida a las 417.00.
# Se traslada el paciente: Paciente-134 a la hora 417.00.
# Sintomas:  1
# Paciente [Paciente-129] trasladado a la salida a las 418.00.
# Se traslada el paciente: Paciente-135 a la hora 418.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-134 a la hora 419.00.
# Tiempo tomado:  8  para paciente:  Paciente-134
# Paciente [Paciente-133] trasladado a la salida a las 421.00.
# Sintomas:  1
# Se traslada el paciente: Paciente-136 a la hora 421.00.
# Paciente [Paciente-135] trasladado a la salida a las 422.00.
# Se traslada el paciente: Paciente-137 a la hora 422.00.
# Sintomas:  1
# Paciente [Paciente-136] trasladado a la salida a las 426.00.
# Se traslada el paciente: Paciente-138 a la hora 426.00.
# Paciente  134
# Paciente [Paciente-134] vacunado a las 427.00.
# Sintomas:  1
# Paciente [Paciente-134] trasladado a la salida a las 428.00.
# Se traslada el paciente: Paciente-139 a la hora 428.00.
# Paciente [Paciente-137] trasladado a la salida a las 429.00.
# Se traslada el paciente: Paciente-140 a la hora 429.00.
# Sintomas:  1
# Paciente [Paciente-138] trasladado a la salida a las 431.00.
# Se traslada el paciente: Paciente-141 a la hora 431.00.
# Llega el paciente: Paciente-442 a la hora 433.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-139 a la hora 433.00.
# Tiempo tomado:  5  para paciente:  Paciente-139
# Sintomas:  1
# Sintomas:  2
# Ingresa el paciente a las Paciente-141 a la hora 433.00.
# Tiempo tomado:  8  para paciente:  Paciente-141
# Paciente [Paciente-140] trasladado a la salida a las 434.00.
# Se traslada el paciente: Paciente-142 a la hora 434.00.
# Sintomas:  1
# Llega el paciente: Paciente-443 a la hora 438.00.
# Paciente  139
# Paciente [Paciente-139] vacunado a las 438.00.
# Paciente [Paciente-142] trasladado a la salida a las 439.00.
# Se traslada el paciente: Paciente-143 a la hora 439.00.
# Paciente  141
# Paciente [Paciente-141] vacunado a las 441.00.
# Paciente [Paciente-139] trasladado a la salida a las 441.00.
# Se traslada el paciente: Paciente-144 a la hora 441.00.
# Paciente [Paciente-141] trasladado a la salida a las 442.00.
# Se traslada el paciente: Paciente-145 a la hora 442.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-143 a la hora 444.00.
# Tiempo tomado:  7  para paciente:  Paciente-143
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-145] trasladado a la salida a las 447.00.
# Se traslada el paciente: Paciente-146 a la hora 447.00.
# Paciente [Paciente-144] trasladado a la salida a las 448.00.
# Se traslada el paciente: Paciente-147 a la hora 448.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-146 a la hora 450.00.
# Tiempo tomado:  10  para paciente:  Paciente-146
# Paciente  143
# Paciente [Paciente-143] vacunado a las 451.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-147 a la hora 451.00.
# Tiempo tomado:  5  para paciente:  Paciente-147
# Llega el paciente: Paciente-444 a la hora 452.00.
# Paciente [Paciente-143] trasladado a la salida a las 452.00.
# Se traslada el paciente: Paciente-148 a la hora 452.00.
# Llega el paciente: Paciente-445 a la hora 454.00.
# Paciente  147
# Paciente [Paciente-147] vacunado a las 456.00.
# Sintomas:  1
# Paciente [Paciente-147] trasladado a la salida a las 457.00.
# Se traslada el paciente: Paciente-149 a la hora 457.00.
# Paciente [Paciente-148] trasladado a la salida a las 458.00.
# Se traslada el paciente: Paciente-150 a la hora 458.00.
# Sintomas:  1
# Paciente  146
# Paciente [Paciente-146] vacunado a las 460.00.
# Llega el paciente: Paciente-446 a la hora 461.00.
# Paciente [Paciente-149] trasladado a la salida a las 461.00.
# Se traslada el paciente: Paciente-151 a la hora 461.00.
# Paciente [Paciente-146] trasladado a la salida a las 462.00.
# Se traslada el paciente: Paciente-152 a la hora 462.00.
# Sintomas:  1
# Sintomas:  1
# Paciente [Paciente-150] trasladado a la salida a las 465.00.
# Paciente [Paciente-151] trasladado a la salida a las 465.00.
# Se traslada el paciente: Paciente-153 a la hora 465.00.
# Se traslada el paciente: Paciente-154 a la hora 465.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-152 a la hora 466.00.
# Tiempo tomado:  8  para paciente:  Paciente-152
# Sintomas:  2
# Ingresa el paciente a las Paciente-154 a la hora 469.00.
# Tiempo tomado:  6  para paciente:  Paciente-154
# Llega el paciente: Paciente-447 a la hora 470.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-153 a la hora 470.00.
# Tiempo tomado:  7  para paciente:  Paciente-153
# Paciente  152
# Paciente [Paciente-152] vacunado a las 474.00.
# Paciente  154
# Paciente [Paciente-154] vacunado a las 475.00.
# Paciente [Paciente-152] trasladado a la salida a las 475.00.
# Se traslada el paciente: Paciente-155 a la hora 475.00.
# Paciente [Paciente-154] trasladado a la salida a las 476.00.
# Se traslada el paciente: Paciente-156 a la hora 476.00.
# Paciente  153
# Paciente [Paciente-153] vacunado a las 477.00.
# Sintomas:  2
# Ingresa el paciente a las Paciente-156 a la hora 478.00.
# Tiempo tomado:  5  para paciente:  Paciente-156
# Paciente [Paciente-153] trasladado a la salida a las 478.00.
# Se traslada el paciente: Paciente-157 a la hora 478.00.
# Sintomas:  1

# %%
# Generamos la grafica
datos = sorted(tiempo_vacunacion.items())
print(datos)
x, y = zip(*datos)
result = plt.hist(x,color='blue',edgecolor='m',alpha=0.7)
plt.ylabel("Pacientes")
plt.xlabel("Tiempo tomado")
# Out:
# [(2, 9), (3, 8), (4, 6), (6, 9), (7, 8), (10, 5), (12, 9), (14, 6), (16, 9), (17, 7), (19, 6), (21, 10), (22, 10), (23, 5), (24, 8), (25, 6), (27, 8), (30, 7), (31, 9), (34, 7), (35, 7), (36, 8), (39, 8), (40, 5), (41, 8), (42, 6), (43, 9), (48, 10), (50, 5), (51, 8), (57, 5), (58, 9), (60, 7), (62, 8), (64, 6), (68, 8), (73, 9), (76, 9), (77, 5), (80, 5), (81, 8), (82, 5), (85, 8), (86, 10), (87, 5), (88, 6), (89, 5), (90, 6), (91, 9), (95, 6), (96, 9), (97, 5), (98, 5), (100, 9), (102, 9), (103, 7), (104, 5), (105, 8), (108, 7), (110, 5), (111, 9), (113, 10), (116, 8), (117, 9), (118, 8), (119, 5), (122, 5), (124, 8), (129, 8), (131, 6), (134, 8), (139, 5), (141, 8), (143, 7), (146, 10), (147, 5), (152, 8), (153, 7), (154, 6)]
# Text(0.5, 0, 'Tiempo tomado')

# %%
suma = 0
for val in tuple(tiempo_vacunacion.values()):
    suma = suma+val
print("Promedio de tiempo vacunacion",suma/len(tiempo_vacunacion))
# Out:
# Promedio de tiempo vacunacion 7.265822784810126

# %%
print("Total de pacientes que llegaron ",PACIENTES)
print("Vacunados ", len(p_vacunado))
print("No vacunados ", len(p_no_vacunado))
n_atendidos = PACIENTES-(len(p_vacunado)+len(p_no_vacunado))
print("Pacientes no atendidos",n_atendidos)
# Out:
# Total de pacientes que llegaron  400
# Vacunados  79
# No vacunados  76
# Pacientes no atendidos 245
