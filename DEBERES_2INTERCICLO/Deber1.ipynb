# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielChuchuca/SIMULACION/blob/main/Deber1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.0.1-py2.py3-none-any.whl (29 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.0.1

# %% [markdown]
# ![WhatsApp Image 2021-07-30 at 21.41.05 (1).jpeg](data:image/jpeg;base64,...)

# %%
import simpy
import random 
import datetime as dt
from datetime import datetime

# %%
MESAS = 10 
TIEMPO_VACUNACION = 5
SEMANAS = 2
TIEMPO_SIMULACION =  SEMANAS *3*9*60
CONTROL_SIGNOS = 1
TIEMPO_POST_VACUNA = 20

tiempo_vacunacion={}
cont={0:1}
FECHA_ACTUAL = datetime.now().strftime('%d/%m/%Y')

# %%
personas_reasignadas={}
tiempo_vacunacion={}
estado_personas={}

# %%
class VacunasEstado():
    def __init__(self, env):
        self.env = env
        self.dispensador = simpy.Resource(env, capacity=MESAS)
        self.bodega = simpy.Container(env, init=350, capacity=800)
        self.monitoreo = env.process(self.monitoreo_bodega())
    def monitoreo_bodega(self,):
        while True:
            if self.bodega.level <= 10:
                self.logs_procesos('++++','Solicitar nuevas vacunas ', self.env.now)
                env.process(self.solicitar_vacunas())
            yield self.env.timeout(15)
    def solicitar_vacunas(self,):
        yield self.env.timeout(50)
        self.logs_procesos('','llega suministro vacunas ',self.env.now)
        nivel = self.bodega.capacity - self.bodega.level
        if nivel ==0:
            nivel+=1
        yield self.bodega.put(nivel)
        
    def logs_procesos(self,icon, accion, hora):
        print(" %s accion:  [%s] hora:  [%d] "%(icon, accion, hora))

# %%
class Vacunacion():
    def __init__(self, env, nombre, estadoVacunas):
        self.env = env
        self.nombre = nombre 
        self.estado_vacunas = estadoVacunas
        self.proceso = env.process(self.proceso_vacunacion())
        self.personas_vacunadas = 0
    def control_signos(self):
        yield self.env.timeout(random.randint(CONTROL_SIGNOS, CONTROL_SIGNOS+2))
    
    def logs_procesos(self,icon,nombre, accion, hora):
        print(" %s nombre: [%s] accion:  [%s] hora:  [%d] "%(icon,nombre, accion, hora))
    
    def aplicar_vacuna(self):
        yield self.env.timeout(random.randint(TIEMPO_VACUNACION, TIEMPO_VACUNACION+5))
        
    def post_vacuna(self, tiempo):
        yield self.env.timeout(tiempo)
    
    def proceso_vacunacion(self,):
        while True:
            nombre= 'persona '+str(cont[0])
            cont[0]=cont[0]+1
            self.logs_procesos("--->",nombre," llega al recinto",self.env.now)
            estado_personas[nombre]='cola'
            yield env.process(self.control_signos())
            if random.randint(1,100) > 10:
                self.logs_procesos("", nombre, "pasa el control", env.now)
                estado_personas[nombre]='pasa control'
                inicio_vacunacion =  self.env.now
                if self.estado_vacunas.bodega.level >=1:
                    yield env.process(self.aplicar_vacuna())
                    estado_personas[nombre]='vacunado'
                    self.estado_vacunas.bodega.get(1)
                    tiempo_vacunacion[nombre] = self.env.now - inicio_vacunacion
                    self.logs_procesos("", nombre, "fue vacunada ", self.env.now)
                    yield env.process(self.post_vacuna(TIEMPO_POST_VACUNA))
                    self.logs_procesos("", nombre, "sin complicaciones", self.env.now)
                    self.personas_vacunadas += 1
                    estado_personas[nombre]='completo'
                    
                else:
                    prox_cita = datetime.strftime(datetime.strptime(FECHA_ACTUAL, '%d/%m/%Y')+dt.timedelta(days=3), '%d/%m/%Y')
                    print("--XX-- No hay vacunas para %s, reasignado fecha para: %s"%(nombre, prox_cita))
                    personas_reasignadas[nombre]='reasignado'
                    estado_personas[nombre]='reasignado'
                                
            else:
                self.logs_procesos("", nombre,"no pasa el control", self.env.now)
                estado_personas[nombre]='no control'

# %%
env = simpy.Environment()

vacunasEstado = VacunasEstado(env)
vacunacion =[Vacunacion(env,"Mesa %d"% i, vacunasEstado) for i in range(MESAS)]
env.run(until=TIEMPO_SIMULACION)
print("Simulacion realizada despues de %d semanas"%SEMANAS)
for i in vacunacion:
    print("[%s] ha vacunado a [%d] personas"%(i.nombre,i.personas_vacunadas))
# Out:
#  ---> nombre: [persona 1] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 2] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 3] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 4] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 5] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 6] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 7] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 8] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 9] accion:  [ llega al recinto] hora:  [0]
#  ---> nombre: [persona 10] accion:  [ llega al recinto] hora:  [0]
#   nombre: [persona 8] accion:  [pasa el control] hora:  [1]
#   nombre: [persona 1] accion:  [pasa el control] hora:  [2]
#   nombre: [persona 2] accion:  [pasa el control] hora:  [2]
#   nombre: [persona 3] accion:  [pasa el control] hora:  [2]
#   nombre: [persona 4] accion:  [pasa el control] hora:  [2]
#   nombre: [persona 6] accion:  [pasa el control] hora:  [2]
#   nombre: [persona 10] accion:  [pasa el control] hora:  [2]
#   nombre: [persona 5] accion:  [pasa el control] hora:  [3]
#   nombre: [persona 7] accion:  [pasa el control] hora:  [3]
#   nombre: [persona 9] accion:  [pasa el control] hora:  [3]
#   nombre: [persona 8] accion:  [fue vacunada ] hora:  [7]
#   nombre: [persona 3] accion:  [fue vacunada ] hora:  [7]
#   nombre: [persona 7] accion:  [fue vacunada ] hora:  [8]
#   nombre: [persona 2] accion:  [fue vacunada ] hora:  [9]
#   nombre: [persona 10] accion:  [fue vacunada ] hora:  [9]
#   nombre: [persona 9] accion:  [fue vacunada ] hora:  [10]
#   nombre: [persona 4] accion:  [fue vacunada ] hora:  [11]
#   nombre: [persona 6] accion:  [fue vacunada ] hora:  [11]
#   nombre: [persona 1] accion:  [fue vacunada ] hora:  [12]
#   nombre: [persona 5] accion:  [fue vacunada ] hora:  [12]
#   nombre: [persona 8] accion:  [sin complicaciones] hora:  [27]
#  ---> nombre: [persona 11] accion:  [ llega al recinto] hora:  [27]
#   nombre: [persona 3] accion:  [sin complicaciones] hora:  [27]
#  ---> nombre: [persona 12] accion:  [ llega al recinto] hora:  [27]
#   nombre: [persona 7] accion:  [sin complicaciones] hora:  [28]
#  ---> nombre: [persona 13] accion:  [ llega al recinto] hora:  [28]
#   nombre: [persona 2] accion:  [sin complicaciones] hora:  [29]
#  ---> nombre: [persona 14] accion:  [ llega al recinto] hora:  [29]
#   nombre: [persona 10] accion:  [sin complicaciones] hora:  [29]
#  ---> nombre: [persona 15] accion:  [ llega al recinto] hora:  [29]
#   nombre: [persona 12] accion:  [pasa el control] hora:  [29]
#   nombre: [persona 9] accion:  [sin complicaciones] hora:  [30]
#  ---> nombre: [persona 16] accion:  [ llega al recinto] hora:  [30]
#   nombre: [persona 11] accion:  [pasa el control] hora:  [30]
#   nombre: [persona 13] accion:  [pasa el control] hora:  [30]
#   nombre: [persona 14] accion:  [pasa el control] hora:  [30]
#   nombre: [persona 15] accion:  [pasa el control] hora:  [30]
#   nombre: [persona 4] accion:  [sin complicaciones] hora:  [31]
#  ---> nombre: [persona 17] accion:  [ llega al recinto] hora:  [31]
#   nombre: [persona 6] accion:  [sin complicaciones] hora:  [31]
#  ---> nombre: [persona 18] accion:  [ llega al recinto] hora:  [31]
#   nombre: [persona 16] accion:  [no pasa el control] hora:  [31]
#  ---> nombre: [persona 19] accion:  [ llega al recinto] hora:  [31]
#   nombre: [persona 1] accion:  [sin complicaciones] hora:  [32]
#  ---> nombre: [persona 20] accion:  [ llega al recinto] hora:  [32]
#   nombre: [persona 5] accion:  [sin complicaciones] hora:  [32]
#  ---> nombre: [persona 21] accion:  [ llega al recinto] hora:  [32]
#   nombre: [persona 18] accion:  [pasa el control] hora:  [32]
#   nombre: [persona 19] accion:  [pasa el control] hora:  [32]
#   nombre: [persona 17] accion:  [no pasa el control] hora:  [33]
#  ---> nombre: [persona 22] accion:  [ llega al recinto] hora:  [33]
#   nombre: [persona 20] accion:  [pasa el control] hora:  [33]
#   nombre: [persona 21] accion:  [pasa el control] hora:  [33]
#   nombre: [persona 22] accion:  [pasa el control] hora:  [35]
#   nombre: [persona 14] accion:  [fue vacunada ] hora:  [36]
#   nombre: [persona 15] accion:  [fue vacunada ] hora:  [36]
#   nombre: [persona 12] accion:  [fue vacunada ] hora:  [37]
#   nombre: [persona 11] accion:  [fue vacunada ] hora:  [38]
#   nombre: [persona 21] accion:  [fue vacunada ] hora:  [39]
#   nombre: [persona 13] accion:  [fue vacunada ] hora:  [40]
#   nombre: [persona 18] accion:  [fue vacunada ] hora:  [41]
#   nombre: [persona 19] accion:  [fue vacunada ] hora:  [41]
#   nombre: [persona 20] accion:  [fue vacunada ] hora:  [42]
#   nombre: [persona 22] accion:  [fue vacunada ] hora:  [44]
#   nombre: [persona 14] accion:  [sin complicaciones] hora:  [56]
#  ---> nombre: [persona 23] accion:  [ llega al recinto] hora:  [56]
#   nombre: [persona 15] accion:  [sin complicaciones] hora:  [56]
#  ---> nombre: [persona 24] accion:  [ llega al recinto] hora:  [56]
#   nombre: [persona 12] accion:  [sin complicaciones] hora:  [57]
#  ---> nombre: [persona 25] accion:  [ llega al recinto] hora:  [57]
#   nombre: [persona 11] accion:  [sin complicaciones] hora:  [58]
#  ---> nombre: [persona 26] accion:  [ llega al recinto] hora:  [58]
#   nombre: [persona 23] accion:  [pasa el control] hora:  [58]
#   nombre: [persona 21] accion:  [sin complicaciones] hora:  [59]
#  ---> nombre: [persona 27] accion:  [ llega al recinto] hora:  [59]
#   nombre: [persona 24] accion:  [pasa el control] hora:  [59]
#   nombre: [persona 25] accion:  [no pasa el control] hora:  [59]
#  ---> nombre: [persona 28] accion:  [ llega al recinto] hora:  [59]
#   nombre: [persona 13] accion:  [sin complicaciones] hora:  [60]
#  ---> nombre: [persona 29] accion:  [ llega al recinto] hora:  [60]
#   nombre: [persona 26] accion:  [pasa el control] hora:  [60]
#   nombre: [persona 27] accion:  [pasa el control] hora:  [60]
#   nombre: [persona 18] accion:  [sin complicaciones] hora:  [61]
#  ---> nombre: [persona 30] accion:  [ llega al recinto] hora:  [61]
#   nombre: [persona 19] accion:  [sin complicaciones] hora:  [61]
#  ---> nombre: [persona 31] accion:  [ llega al recinto] hora:  [61]
#   nombre: [persona 28] accion:  [pasa el control] hora:  [61]
#   nombre: [persona 29] accion:  [pasa el control] hora:  [61]
#   nombre: [persona 20] accion:  [sin complicaciones] hora:  [62]
#  ---> nombre: [persona 32] accion:  [ llega al recinto] hora:  [62]
#   nombre: [persona 22] accion:  [sin complicaciones] hora:  [64]
#  ---> nombre: [persona 33] accion:  [ llega al recinto] hora:  [64]
#   nombre: [persona 30] accion:  [pasa el control] hora:  [64]
#   nombre: [persona 31] accion:  [pasa el control] hora:  [64]
#   nombre: [persona 32] accion:  [pasa el control] hora:  [64]
#   nombre: [persona 23] accion:  [fue vacunada ] hora:  [66]
#   nombre: [persona 24] accion:  [fue vacunada ] hora:  [66]
#   nombre: [persona 33] accion:  [pasa el control] hora:  [66]
#   nombre: [persona 28] accion:  [fue vacunada ] hora:  [67]
#   nombre: [persona 27] accion:  [fue vacunada ] hora:  [68]
#   nombre: [persona 26] accion:  [fue vacunada ] hora:  [69]
#   nombre: [persona 29] accion:  [fue vacunada ] hora:  [70]
#   nombre: [persona 30] accion:  [fue vacunada ] hora:  [72]
#   nombre: [persona 31] accion:  [fue vacunada ] hora:  [72]
#   nombre: [persona 32] accion:  [fue vacunada ] hora:  [73]
#   nombre: [persona 33] accion:  [fue vacunada ] hora:  [74]
#   nombre: [persona 23] accion:  [sin complicaciones] hora:  [86]
#  ---> nombre: [persona 34] accion:  [ llega al recinto] hora:  [86]
#   nombre: [persona 24] accion:  [sin complicaciones] hora:  [86]
#  ---> nombre: [persona 35] accion:  [ llega al recinto] hora:  [86]
#   nombre: [persona 28] accion:  [sin complicaciones] hora:  [87]
#  ---> nombre: [persona 36] accion:  [ llega al recinto] hora:  [87]
#   nombre: [persona 27] accion:  [sin complicaciones] hora:  [88]
#  ---> nombre: [persona 37] accion:  [ llega al recinto] hora:  [88]
#   nombre: [persona 34] accion:  [pasa el control] hora:  [88]
#   nombre: [persona 35] accion:  [pasa el control] hora:  [88]
#   nombre: [persona 36] accion:  [no pasa el control] hora:  [88]
#  ---> nombre: [persona 38] accion:  [ llega al recinto] hora:  [88]
#   nombre: [persona 26] accion:  [sin complicaciones] hora:  [89]
#  ---> nombre: [persona 39] accion:  [ llega al recinto] hora:  [89]
#   nombre: [persona 37] accion:  [pasa el control] hora:  [89]
#   nombre: [persona 29] accion:  [sin complicaciones] hora:  [90]
#  ---> nombre: [persona 40] accion:  [ llega al recinto] hora:  [90]
#   nombre: [persona 39] accion:  [no pasa el control] hora:  [90]
#  ---> nombre: [persona 41] accion:  [ llega al recinto] hora:  [90]
#   nombre: [persona 38] accion:  [pasa el control] hora:  [91]
#   nombre: [persona 30] accion:  [sin complicaciones] hora:  [92]
#  ---> nombre: [persona 42] accion:  [ llega al recinto] hora:  [92]
#   nombre: [persona 31] accion:  [sin complicaciones] hora:  [92]
#  ---> nombre: [persona 43] accion:  [ llega al recinto] hora:  [92]
#   nombre: [persona 40] accion:  [no pasa el control] hora:  [92]
#  ---> nombre: [persona 44] accion:  [ llega al recinto] hora:  [92]
#   nombre: [persona 32] accion:  [sin complicaciones] hora:  [93]
#  ---> nombre: [persona 45] accion:  [ llega al recinto] hora:  [93]
#   nombre: [persona 34] accion:  [fue vacunada ] hora:  [93]
#   nombre: [persona 41] accion:  [pasa el control] hora:  [93]
#   nombre: [persona 43] accion:  [no pasa el control] hora:  [93]
#  ---> nombre: [persona 46] accion:  [ llega al recinto] hora:  [93]
#   nombre: [persona 33] accion:  [sin complicaciones] hora:  [94]
#  ---> nombre: [persona 47] accion:  [ llega al recinto] hora:  [94]
#   nombre: [persona 42] accion:  [pasa el control] hora:  [94]
#   nombre: [persona 44] accion:  [pasa el control] hora:  [94]
#   nombre: [persona 37] accion:  [fue vacunada ] hora:  [95]
#   nombre: [persona 45] accion:  [pasa el control] hora:  [95]
#   nombre: [persona 46] accion:  [pasa el control] hora:  [95]
#   nombre: [persona 47] accion:  [pasa el control] hora:  [96]
#   nombre: [persona 35] accion:  [fue vacunada ] hora:  [97]
#   nombre: [persona 38] accion:  [fue vacunada ] hora:  [99]
#   nombre: [persona 44] accion:  [fue vacunada ] hora:  [99]
#   nombre: [persona 42] accion:  [fue vacunada ] hora:  [102]
#   nombre: [persona 41] accion:  [fue vacunada ] hora:  [103]
#   nombre: [persona 45] accion:  [fue vacunada ] hora:  [103]
#   nombre: [persona 46] accion:  [fue vacunada ] hora:  [105]
#   nombre: [persona 47] accion:  [fue vacunada ] hora:  [105]
#   nombre: [persona 34] accion:  [sin complicaciones] hora:  [113]
#  ---> nombre: [persona 48] accion:  [ llega al recinto] hora:  [113]
#   nombre: [persona 48] accion:  [pasa el control] hora:  [114]
#   nombre: [persona 37] accion:  [sin complicaciones] hora:  [115]
#  ---> nombre: [persona 49] accion:  [ llega al recinto] hora:  [115]
#   nombre: [persona 35] accion:  [sin complicaciones] hora:  [117]
#  ---> nombre: [persona 50] accion:  [ llega al recinto] hora:  [117]
#   nombre: [persona 49] accion:  [no pasa el control] hora:  [118]
#  ---> nombre: [persona 51] accion:  [ llega al recinto] hora:  [118]
#   nombre: [persona 38] accion:  [sin complicaciones] hora:  [119]
#  ---> nombre: [persona 52] accion:  [ llega al recinto] hora:  [119]
#   nombre: [persona 44] accion:  [sin complicaciones] hora:  [119]
#  ---> nombre: [persona 53] accion:  [ llega al recinto] hora:  [119]
#   nombre: [persona 50] accion:  [pasa el control] hora:  [119]
#   nombre: [persona 51] accion:  [pasa el control] hora:  [120]
#   nombre: [persona 52] accion:  [pasa el control] hora:  [121]
#   nombre: [persona 53] accion:  [pasa el control] hora:  [121]
#   nombre: [persona 42] accion:  [sin complicaciones] hora:  [122]
#  ---> nombre: [persona 54] accion:  [ llega al recinto] hora:  [122]
#   nombre: [persona 41] accion:  [sin complicaciones] hora:  [123]
#  ---> nombre: [persona 55] accion:  [ llega al recinto] hora:  [123]
#   nombre: [persona 45] accion:  [sin complicaciones] hora:  [123]
#  ---> nombre: [persona 56] accion:  [ llega al recinto] hora:  [123]
#   nombre: [persona 48] accion:  [fue vacunada ] hora:  [124]
#   nombre: [persona 54] accion:  [pasa el control] hora:  [124]
#   nombre: [persona 55] accion:  [pasa el control] hora:  [124]
#   nombre: [persona 56] accion:  [pasa el control] hora:  [124]
#   nombre: [persona 46] accion:  [sin complicaciones] hora:  [125]
#  ---> nombre: [persona 57] accion:  [ llega al recinto] hora:  [125]
#   nombre: [persona 47] accion:  [sin complicaciones] hora:  [125]
#  ---> nombre: [persona 58] accion:  [ llega al recinto] hora:  [125]
#   nombre: [persona 50] accion:  [fue vacunada ] hora:  [127]
#   nombre: [persona 57] accion:  [pasa el control] hora:  [128]
#   nombre: [persona 58] accion:  [pasa el control] hora:  [128]
#   nombre: [persona 51] accion:  [fue vacunada ] hora:  [129]
#   nombre: [persona 53] accion:  [fue vacunada ] hora:  [129]
#   nombre: [persona 52] accion:  [fue vacunada ] hora:  [130]
#   nombre: [persona 56] accion:  [fue vacunada ] hora:  [131]
#   nombre: [persona 54] accion:  [fue vacunada ] hora:  [133]
#   nombre: [persona 55] accion:  [fue vacunada ] hora:  [133]
#   nombre: [persona 57] accion:  [fue vacunada ] hora:  [135]
#   nombre: [persona 58] accion:  [fue vacunada ] hora:  [138]
#   nombre: [persona 48] accion:  [sin complicaciones] hora:  [144]
#  ---> nombre: [persona 59] accion:  [ llega al recinto] hora:  [144]
#   nombre: [persona 59] accion:  [pasa el control] hora:  [145]
#   nombre: [persona 50] accion:  [sin complicaciones] hora:  [147]
#  ---> nombre: [persona 60] accion:  [ llega al recinto] hora:  [147]
#   nombre: [persona 60] accion:  [pasa el control] hora:  [148]
#   nombre: [persona 51] accion:  [sin complicaciones] hora:  [149]
#  ---> nombre: [persona 61] accion:  [ llega al recinto] hora:  [149]
#   nombre: [persona 53] accion:  [sin complicaciones] hora:  [149]
#  ---> nombre: [persona 62] accion:  [ llega al recinto] hora:  [149]
#   nombre: [persona 52] accion:  [sin complicaciones] hora:  [150]
#  ---> nombre: [persona 63] accion:  [ llega al recinto] hora:  [150]
#   nombre: [persona 62] accion:  [pasa el control] hora:  [150]
#   nombre: [persona 56] accion:  [sin complicaciones] hora:  [151]
#  ---> nombre: [persona 64] accion:  [ llega al recinto] hora:  [151]
#   nombre: [persona 61] accion:  [pasa el control] hora:  [151]
#   nombre: [persona 63] accion:  [pasa el control] hora:  [151]
#   nombre: [persona 59] accion:  [fue vacunada ] hora:  [152]
#   nombre: [persona 54] accion:  [sin complicaciones] hora:  [153]
#  ---> nombre: [persona 65] accion:  [ llega al recinto] hora:  [153]
#   nombre: [persona 55] accion:  [sin complicaciones] hora:  [153]
#  ---> nombre: [persona 66] accion:  [ llega al recinto] hora:  [153]
#   nombre: [persona 64] accion:  [pasa el control] hora:  [154]
#   nombre: [persona 66] accion:  [no pasa el control] hora:  [154]
#  ---> nombre: [persona 67] accion:  [ llega al recinto] hora:  [154]
#   nombre: [persona 57] accion:  [sin complicaciones] hora:  [155]
#  ---> nombre: [persona 68] accion:  [ llega al recinto] hora:  [155]
#   nombre: [persona 60] accion:  [fue vacunada ] hora:  [156]
#   nombre: [persona 61] accion:  [fue vacunada ] hora:  [156]
#   nombre: [persona 63] accion:  [fue vacunada ] hora:  [156]
#   nombre: [persona 65] accion:  [pasa el control] hora:  [156]
#   nombre: [persona 67] accion:  [pasa el control] hora:  [156]
#   nombre: [persona 68] accion:  [pasa el control] hora:  [157]
#   nombre: [persona 58] accion:  [sin complicaciones] hora:  [158]
#  ---> nombre: [persona 69] accion:  [ llega al recinto] hora:  [158]
#   nombre: [persona 69] accion:  [no pasa el control] hora:  [159]
#  ---> nombre: [persona 70] accion:  [ llega al recinto] hora:  [159]
#   nombre: [persona 62] accion:  [fue vacunada ] hora:  [160]
#   nombre: [persona 70] accion:  [pasa el control] hora:  [160]
#   nombre: [persona 65] accion:  [fue vacunada ] hora:  [161]
#   nombre: [persona 64] accion:  [fue vacunada ] hora:  [164]
#   nombre: [persona 67] accion:  [fue vacunada ] hora:  [164]
#   nombre: [persona 68] accion:  [fue vacunada ] hora:  [164]
#   nombre: [persona 70] accion:  [fue vacunada ] hora:  [169]
#   nombre: [persona 59] accion:  [sin complicaciones] hora:  [172]
#  ---> nombre: [persona 71] accion:  [ llega al recinto] hora:  [172]
#   nombre: [persona 71] accion:  [no pasa el control] hora:  [173]
#  ---> nombre: [persona 72] accion:  [ llega al recinto] hora:  [173]
#   nombre: [persona 60] accion:  [sin complicaciones] hora:  [176]
#  ---> nombre: [persona 73] accion:  [ llega al recinto] hora:  [176]
#   nombre: [persona 61] accion:  [sin complicaciones] hora:  [176]
#  ---> nombre: [persona 74] accion:  [ llega al recinto] hora:  [176]
#   nombre: [persona 63] accion:  [sin complicaciones] hora:  [176]
#  ---> nombre: [persona 75] accion:  [ llega al recinto] hora:  [176]
#   nombre: [persona 72] accion:  [pasa el control] hora:  [176]
#   nombre: [persona 73] accion:  [pasa el control] hora:  [177]
#   nombre: [persona 75] accion:  [pasa el control] hora:  [177]
#   nombre: [persona 74] accion:  [pasa el control] hora:  [179]
#   nombre: [persona 62] accion:  [sin complicaciones] hora:  [180]
#  ---> nombre: [persona 76] accion:  [ llega al recinto] hora:  [180]
#   nombre: [persona 65] accion:  [sin complicaciones] hora:  [181]
#  ---> nombre: [persona 77] accion:  [ llega al recinto] hora:  [181]
#   nombre: [persona 72] accion:  [fue vacunada ] hora:  [181]
#   nombre: [persona 76] accion:  [no pasa el control] hora:  [182]
#  ---> nombre: [persona 78] accion:  [ llega al recinto] hora:  [182]
#   nombre: [persona 77] accion:  [pasa el control] hora:  [183]
#   nombre: [persona 78] accion:  [no pasa el control] hora:  [183]
#  ---> nombre: [persona 79] accion:  [ llega al recinto] hora:  [183]
#   nombre: [persona 64] accion:  [sin complicaciones] hora:  [184]
#  ---> nombre: [persona 80] accion:  [ llega al recinto] hora:  [184]
#   nombre: [persona 67] accion:  [sin complicaciones] hora:  [184]
#  ---> nombre: [persona 81] accion:  [ llega al recinto] hora:  [184]
#   nombre: [persona 68] accion:  [sin complicaciones] hora:  [184]
#  ---> nombre: [persona 82] accion:  [ llega al recinto] hora:  [184]
#   nombre: [persona 73] accion:  [fue vacunada ] hora:  [184]
#   nombre: [persona 74] accion:  [fue vacunada ] hora:  [185]
#   nombre: [persona 79] accion:  [pasa el control] hora:  [185]
#   nombre: [persona 81] accion:  [pasa el control] hora:  [185]
#   nombre: [persona 82] accion:  [pasa el control] hora:  [185]
#   nombre: [persona 80] accion:  [pasa el control] hora:  [186]
#   nombre: [persona 75] accion:  [fue vacunada ] hora:  [187]
#   nombre: [persona 70] accion:  [sin complicaciones] hora:  [189]
#  ---> nombre: [persona 83] accion:  [ llega al recinto] hora:  [189]
#   nombre: [persona 77] accion:  [fue vacunada ] hora:  [189]
#   nombre: [persona 80] accion:  [fue vacunada ] hora:  [192]
#   nombre: [persona 83] accion:  [pasa el control] hora:  [192]
#   nombre: [persona 79] accion:  [fue vacunada ] hora:  [193]
#   nombre: [persona 82] accion:  [fue vacunada ] hora:  [194]
#   nombre: [persona 81] accion:  [fue vacunada ] hora:  [195]
#   nombre: [persona 83] accion:  [fue vacunada ] hora:  [199]
#   nombre: [persona 72] accion:  [sin complicaciones] hora:  [201]
#  ---> nombre: [persona 84] accion:  [ llega al recinto] hora:  [201]
#   nombre: [persona 73] accion:  [sin complicaciones] hora:  [204]
#  ---> nombre: [persona 85] accion:  [ llega al recinto] hora:  [204]
#   nombre: [persona 84] accion:  [pasa el control] hora:  [204]
#   nombre: [persona 74] accion:  [sin complicaciones] hora:  [205]
#  ---> nombre: [persona 86] accion:  [ llega al recinto] hora:  [205]
#   nombre: [persona 75] accion:  [sin complicaciones] hora:  [207]
#  ---> nombre: [persona 87] accion:  [ llega al recinto] hora:  [207]
#   nombre: [persona 85] accion:  [pasa el control] hora:  [207]
#   nombre: [persona 86] accion:  [pasa el control] hora:  [207]
#   nombre: [persona 77] accion:  [sin complicaciones] hora:  [209]
#  ---> nombre: [persona 88] accion:  [ llega al recinto] hora:  [209]
#   nombre: [persona 87] accion:  [pasa el control] hora:  [210]
#   nombre: [persona 88] accion:  [pasa el control] hora:  [211]
#   nombre: [persona 80] accion:  [sin complicaciones] hora:  [212]
#  ---> nombre: [persona 89] accion:  [ llega al recinto] hora:  [212]
#   nombre: [persona 84] accion:  [fue vacunada ] hora:  [212]
#   nombre: [persona 79] accion:  [sin complicaciones] hora:  [213]
#  ---> nombre: [persona 90] accion:  [ llega al recinto] hora:  [213]
#   nombre: [persona 82] accion:  [sin complicaciones] hora:  [214]
#  ---> nombre: [persona 91] accion:  [ llega al recinto] hora:  [214]
#   nombre: [persona 86] accion:  [fue vacunada ] hora:  [214]
#   nombre: [persona 89] accion:  [pasa el control] hora:  [214]
#   nombre: [persona 90] accion:  [pasa el control] hora:  [214]
#   nombre: [persona 81] accion:  [sin complicaciones] hora:  [215]
#  ---> nombre: [persona 92] accion:  [ llega al recinto] hora:  [215]
#   nombre: [persona 85] accion:  [fue vacunada ] hora:  [215]
#   nombre: [persona 87] accion:  [fue vacunada ] hora:  [215]
#   nombre: [persona 91] accion:  [pasa el control] hora:  [217]
#   nombre: [persona 92] accion:  [pasa el control] hora:  [217]
#   nombre: [persona 88] accion:  [fue vacunada ] hora:  [218]
#   nombre: [persona 83] accion:  [sin complicaciones] hora:  [219]
#  ---> nombre: [persona 93] accion:  [ llega al recinto] hora:  [219]
#   nombre: [persona 90] accion:  [fue vacunada ] hora:  [219]
#   nombre: [persona 93] accion:  [pasa el control] hora:  [221]
#   nombre: [persona 89] accion:  [fue vacunada ] hora:  [222]
#   nombre: [persona 92] accion:  [fue vacunada ] hora:  [224]
#   nombre: [persona 91] accion:  [fue vacunada ] hora:  [227]
#   nombre: [persona 93] accion:  [fue vacunada ] hora:  [228]
#   nombre: [persona 84] accion:  [sin complicaciones] hora:  [232]
#  ---> nombre: [persona 94] accion:  [ llega al recinto] hora:  [232]
#   nombre: [persona 86] accion:  [sin complicaciones] hora:  [234]
#  ---> nombre: [persona 95] accion:  [ llega al recinto] hora:  [234]
#   nombre: [persona 85] accion:  [sin complicaciones] hora:  [235]
#  ---> nombre: [persona 96] accion:  [ llega al recinto] hora:  [235]
#   nombre: [persona 87] accion:  [sin complicaciones] hora:  [235]
#  ---> nombre: [persona 97] accion:  [ llega al recinto] hora:  [235]
#   nombre: [persona 94] accion:  [pasa el control] hora:  [235]
#   nombre: [persona 95] accion:  [pasa el control] hora:  [235]
#   nombre: [persona 97] accion:  [pasa el control] hora:  [236]
#   nombre: [persona 96] accion:  [no pasa el control] hora:  [237]
#  ---> nombre: [persona 98] accion:  [ llega al recinto] hora:  [237]
#   nombre: [persona 88] accion:  [sin complicaciones] hora:  [238]
#  ---> nombre: [persona 99] accion:  [ llega al recinto] hora:  [238]
#   nombre: [persona 90] accion:  [sin complicaciones] hora:  [239]
#  ---> nombre: [persona 100] accion:  [ llega al recinto] hora:  [239]
#   nombre: [persona 98] accion:  [pasa el control] hora:  [240]
#   nombre: [persona 99] accion:  [pasa el control] hora:  [240]
#   nombre: [persona 100] accion:  [pasa el control] hora:  [240]
#   nombre: [persona 95] accion:  [fue vacunada ] hora:  [241]
#   nombre: [persona 89] accion:  [sin complicaciones] hora:  [242]
#  ---> nombre: [persona 101] accion:  [ llega al recinto] hora:  [242]
#   nombre: [persona 97] accion:  [fue vacunada ] hora:  [243]
#   nombre: [persona 92] accion:  [sin complicaciones] hora:  [244]
#  ---> nombre: [persona 102] accion:  [ llega al recinto] hora:  [244]
#   nombre: [persona 101] accion:  [pasa el control] hora:  [244]
#   nombre: [persona 94] accion:  [fue vacunada ] hora:  [245]
#   nombre: [persona 100] accion:  [fue vacunada ] hora:  [245]
#   nombre: [persona 98] accion:  [fue vacunada ] hora:  [246]
#   nombre: [persona 91] accion:  [sin complicaciones] hora:  [247]
#  ---> nombre: [persona 103] accion:  [ llega al recinto] hora:  [247]
#   nombre: [persona 102] accion:  [pasa el control] hora:  [247]
#   nombre: [persona 93] accion:  [sin complicaciones] hora:  [248]
#  ---> nombre: [persona 104] accion:  [ llega al recinto] hora:  [248]
#   nombre: [persona 99] accion:  [fue vacunada ] hora:  [250]
#   nombre: [persona 103] accion:  [pasa el control] hora:  [250]
#   nombre: [persona 104] accion:  [pasa el control] hora:  [250]
#   nombre: [persona 101] accion:  [fue vacunada ] hora:  [253]
#   nombre: [persona 102] accion:  [fue vacunada ] hora:  [253]
#   nombre: [persona 103] accion:  [fue vacunada ] hora:  [257]
#   nombre: [persona 104] accion:  [fue vacunada ] hora:  [258]
#   nombre: [persona 95] accion:  [sin complicaciones] hora:  [261]
#  ---> nombre: [persona 105] accion:  [ llega al recinto] hora:  [261]
#   nombre: [persona 97] accion:  [sin complicaciones] hora:  [263]
#  ---> nombre: [persona 106] accion:  [ llega al recinto] hora:  [263]
#   nombre: [persona 105] accion:  [pasa el control] hora:  [263]
#   nombre: [persona 106] accion:  [pasa el control] hora:  [264]
#   nombre: [persona 94] accion:  [sin complicaciones] hora:  [265]
#  ---> nombre: [persona 107] accion:  [ llega al recinto] hora:  [265]
#   nombre: [persona 100] accion:  [sin complicaciones] hora:  [265]
#  ---> nombre: [persona 108] accion:  [ llega al recinto] hora:  [265]
#   nombre: [persona 98] accion:  [sin complicaciones] hora:  [266]
#  ---> nombre: [persona 109] accion:  [ llega al recinto] hora:  [266]
#   nombre: [persona 107] accion:  [pasa el control] hora:  [266]
#   nombre: [persona 108] accion:  [pasa el control] hora:  [267]
#   nombre: [persona 105] accion:  [fue vacunada ] hora:  [269]
#   nombre: [persona 109] accion:  [no pasa el control] hora:  [269]
#  ---> nombre: [persona 110] accion:  [ llega al recinto] hora:  [269]
#   nombre: [persona 99] accion:  [sin complicaciones] hora:  [270]
#  ---> nombre: [persona 111] accion:  [ llega al recinto] hora:  [270]
#   nombre: [persona 110] accion:  [pasa el control] hora:  [271]
#   nombre: [persona 106] accion:  [fue vacunada ] hora:  [272]
#   nombre: [persona 111] accion:  [pasa el control] hora:  [272]
#   nombre: [persona 101] accion:  [sin complicaciones] hora:  [273]
#  ---> nombre: [persona 112] accion:  [ llega al recinto] hora:  [273]
#   nombre: [persona 102] accion:  [sin complicaciones] hora:  [273]
#  ---> nombre: [persona 113] accion:  [ llega al recinto] hora:  [273]
#   nombre: [persona 108] accion:  [fue vacunada ] hora:  [273]
#   nombre: [persona 113] accion:  [pasa el control] hora:  [274]
#   nombre: [persona 107] accion:  [fue vacunada ] hora:  [275]
#   nombre: [persona 112] accion:  [pasa el control] hora:  [276]
#   nombre: [persona 103] accion:  [sin complicaciones] hora:  [277]
#  ---> nombre: [persona 114] accion:  [ llega al recinto] hora:  [277]
#   nombre: [persona 104] accion:  [sin complicaciones] hora:  [278]
#  ---> nombre: [persona 115] accion:  [ llega al recinto] hora:  [278]
#   nombre: [persona 111] accion:  [fue vacunada ] hora:  [278]
#   nombre: [persona 114] accion:  [pasa el control] hora:  [279]
#   nombre: [persona 115] accion:  [pasa el control] hora:  [279]
#   nombre: [persona 110] accion:  [fue vacunada ] hora:  [281]
#   nombre: [persona 113] accion:  [fue vacunada ] hora:  [283]
#   nombre: [persona 112] accion:  [fue vacunada ] hora:  [284]
#   nombre: [persona 114] accion:  [fue vacunada ] hora:  [284]
#   nombre: [persona 105] accion:  [sin complicaciones] hora:  [289]
#  ---> nombre: [persona 116] accion:  [ llega al recinto] hora:  [289]
#   nombre: [persona 115] accion:  [fue vacunada ] hora:  [289]
#   nombre: [persona 106] accion:  [sin complicaciones] hora:  [292]
#  ---> nombre: [persona 117] accion:  [ llega al recinto] hora:  [292]
#   nombre: [persona 116] accion:  [pasa el control] hora:  [292]
#   nombre: [persona 108] accion:  [sin complicaciones] hora:  [293]
#  ---> nombre: [persona 118] accion:  [ llega al recinto] hora:  [293]
#   nombre: [persona 117] accion:  [pasa el control] hora:  [294]
#   nombre: [persona 118] accion:  [pasa el control] hora:  [294]
#   nombre: [persona 107] accion:  [sin complicaciones] hora:  [295]
#  ---> nombre: [persona 119] accion:  [ llega al recinto] hora:  [295]
#   nombre: [persona 111] accion:  [sin complicaciones] hora:  [298]
#  ---> nombre: [persona 120] accion:  [ llega al recinto] hora:  [298]
#   nombre: [persona 116] accion:  [fue vacunada ] hora:  [298]
#   nombre: [persona 119] accion:  [pasa el control] hora:  [298]
#   nombre: [persona 117] accion:  [fue vacunada ] hora:  [299]
#   nombre: [persona 110] accion:  [sin complicaciones] hora:  [301]
#  ---> nombre: [persona 121] accion:  [ llega al recinto] hora:  [301]
#   nombre: [persona 120] accion:  [pasa el control] hora:  [301]
#   nombre: [persona 113] accion:  [sin complicaciones] hora:  [303]
#  ---> nombre: [persona 122] accion:  [ llega al recinto] hora:  [303]
#   nombre: [persona 119] accion:  [fue vacunada ] hora:  [303]
#   nombre: [persona 121] accion:  [pasa el control] hora:  [303]
#   nombre: [persona 112] accion:  [sin complicaciones] hora:  [304]
#  ---> nombre: [persona 123] accion:  [ llega al recinto] hora:  [304]
#   nombre: [persona 114] accion:  [sin complicaciones] hora:  [304]
#  ---> nombre: [persona 124] accion:  [ llega al recinto] hora:  [304]
#   nombre: [persona 118] accion:  [fue vacunada ] hora:  [304]
#   nombre: [persona 123] accion:  [pasa el control] hora:  [305]
#   nombre: [persona 120] accion:  [fue vacunada ] hora:  [306]
#   nombre: [persona 122] accion:  [no pasa el control] hora:  [306]
#  ---> nombre: [persona 125] accion:  [ llega al recinto] hora:  [306]
#   nombre: [persona 124] accion:  [pasa el control] hora:  [307]
#   nombre: [persona 115] accion:  [sin complicaciones] hora:  [309]
#  ---> nombre: [persona 126] accion:  [ llega al recinto] hora:  [309]
#   nombre: [persona 121] accion:  [fue vacunada ] hora:  [309]
#   nombre: [persona 125] accion:  [pasa el control] hora:  [309]
#   nombre: [persona 123] accion:  [fue vacunada ] hora:  [312]
#   nombre: [persona 126] accion:  [pasa el control] hora:  [312]
#   nombre: [persona 124] accion:  [fue vacunada ] hora:  [315]
#   nombre: [persona 125] accion:  [fue vacunada ] hora:  [317]
#   nombre: [persona 126] accion:  [fue vacunada ] hora:  [317]
#   nombre: [persona 116] accion:  [sin complicaciones] hora:  [318]
#  ---> nombre: [persona 127] accion:  [ llega al recinto] hora:  [318]
#   nombre: [persona 117] accion:  [sin complicaciones] hora:  [319]
#  ---> nombre: [persona 128] accion:  [ llega al recinto] hora:  [319]
#   nombre: [persona 127] accion:  [no pasa el control] hora:  [319]
#  ---> nombre: [persona 129] accion:  [ llega al recinto] hora:  [319]
#   nombre: [persona 128] accion:  [pasa el control] hora:  [322]
#   nombre: [persona 129] accion:  [pasa el control] hora:  [322]
#   nombre: [persona 119] accion:  [sin complicaciones] hora:  [323]
#  ---> nombre: [persona 130] accion:  [ llega al recinto] hora:  [323]
#   nombre: [persona 118] accion:  [sin complicaciones] hora:  [324]
#  ---> nombre: [persona 131] accion:  [ llega al recinto] hora:  [324]
#   nombre: [persona 130] accion:  [pasa el control] hora:  [325]
#   nombre: [persona 120] accion:  [sin complicaciones] hora:  [326]
#  ---> nombre: [persona 132] accion:  [ llega al recinto] hora:  [326]
#   nombre: [persona 131] accion:  [pasa el control] hora:  [327]
#   nombre: [persona 132] accion:  [pasa el control] hora:  [327]
#   nombre: [persona 128] accion:  [fue vacunada ] hora:  [328]
#   nombre: [persona 121] accion:  [sin complicaciones] hora:  [329]
#  ---> nombre: [persona 133] accion:  [ llega al recinto] hora:  [329]
#   nombre: [persona 130] accion:  [fue vacunada ] hora:  [330]
#   nombre: [persona 129] accion:  [fue vacunada ] hora:  [331]
#   nombre: [persona 123] accion:  [sin complicaciones] hora:  [332]
#  ---> nombre: [persona 134] accion:  [ llega al recinto] hora:  [332]
#   nombre: [persona 133] accion:  [pasa el control] hora:  [332]
#   nombre: [persona 131] accion:  [fue vacunada ] hora:  [334]
#   nombre: [persona 134] accion:  [pasa el control] hora:  [334]
#   nombre: [persona 124] accion:  [sin complicaciones] hora:  [335]
#  ---> nombre: [persona 135] accion:  [ llega al recinto] hora:  [335]
#   nombre: [persona 132] accion:  [fue vacunada ] hora:  [336]
#   nombre: [persona 125] accion:  [sin complicaciones] hora:  [337]
#  ---> nombre: [persona 136] accion:  [ llega al recinto] hora:  [337]
#   nombre: [persona 126] accion:  [sin complicaciones] hora:  [337]
#  ---> nombre: [persona 137] accion:  [ llega al recinto] hora:  [337]
#   nombre: [persona 135] accion:  [pasa el control] hora:  [338]
#   nombre: [persona 133] accion:  [fue vacunada ] hora:  [339]
#   nombre: [persona 136] accion:  [pasa el control] hora:  [339]
#   nombre: [persona 137] accion:  [no pasa el control] hora:  [340]
#  ---> nombre: [persona 138] accion:  [ llega al recinto] hora:  [340]
#   nombre: [persona 134] accion:  [fue vacunada ] hora:  [342]
#   nombre: [persona 138] accion:  [pasa el control] hora:  [342]
#   nombre: [persona 135] accion:  [fue vacunada ] hora:  [346]
#   nombre: [persona 128] accion:  [sin complicaciones] hora:  [348]
#  ---> nombre: [persona 139] accion:  [ llega al recinto] hora:  [348]
#   nombre: [persona 136] accion:  [fue vacunada ] hora:  [348]
#   nombre: [persona 138] accion:  [fue vacunada ] hora:  [349]
#   nombre: [persona 130] accion:  [sin complicaciones] hora:  [350]
#  ---> nombre: [persona 140] accion:  [ llega al recinto] hora:  [350]
#   nombre: [persona 129] accion:  [sin complicaciones] hora:  [351]
#  ---> nombre: [persona 141] accion:  [ llega al recinto] hora:  [351]
#   nombre: [persona 139] accion:  [pasa el control] hora:  [351]
#   nombre: [persona 140] accion:  [pasa el control] hora:  [353]
#   nombre: [persona 131] accion:  [sin complicaciones] hora:  [354]
#  ---> nombre: [persona 142] accion:  [ llega al recinto] hora:  [354]
#   nombre: [persona 141] accion:  [pasa el control] hora:  [354]
#   nombre: [persona 132] accion:  [sin complicaciones] hora:  [356]
#  ---> nombre: [persona 143] accion:  [ llega al recinto] hora:  [356]
#   nombre: [persona 142] accion:  [pasa el control] hora:  [357]
#   nombre: [persona 143] accion:  [pasa el control] hora:  [357]
#   nombre: [persona 133] accion:  [sin complicaciones] hora:  [359]
#  ---> nombre: [persona 144] accion:  [ llega al recinto] hora:  [359]
#   nombre: [persona 139] accion:  [fue vacunada ] hora:  [360]
#   nombre: [persona 141] accion:  [fue vacunada ] hora:  [361]
#   nombre: [persona 144] accion:  [pasa el control] hora:  [361]
#   nombre: [persona 134] accion:  [sin complicaciones] hora:  [362]
#  ---> nombre: [persona 145] accion:  [ llega al recinto] hora:  [362]
#   nombre: [persona 140] accion:  [fue vacunada ] hora:  [363]
#   nombre: [persona 143] accion:  [fue vacunada ] hora:  [364]
#   nombre: [persona 142] accion:  [fue vacunada ] hora:  [365]
#   nombre: [persona 145] accion:  [pasa el control] hora:  [365]
#   nombre: [persona 135] accion:  [sin complicaciones] hora:  [366]
#  ---> nombre: [persona 146] accion:  [ llega al recinto] hora:  [366]
#   nombre: [persona 146] accion:  [pasa el control] hora:  [367]
#   nombre: [persona 136] accion:  [sin complicaciones] hora:  [368]
#  ---> nombre: [persona 147] accion:  [ llega al recinto] hora:  [368]
#   nombre: [persona 138] accion:  [sin complicaciones] hora:  [369]
#  ---> nombre: [persona 148] accion:  [ llega al recinto] hora:  [369]
#   nombre: [persona 144] accion:  [fue vacunada ] hora:  [369]
#   nombre: [persona 147] accion:  [pasa el control] hora:  [369]
#   nombre: [persona 148] accion:  [pasa el control] hora:  [371]
#   nombre: [persona 145] accion:  [fue vacunada ] hora:  [373]
#   nombre: [persona 146] accion:  [fue vacunada ] hora:  [373]
#   nombre: [persona 147] accion:  [fue vacunada ] hora:  [375]
#   nombre: [persona 139] accion:  [sin complicaciones] hora:  [380]
#  ---> nombre: [persona 149] accion:  [ llega al recinto] hora:  [380]
#   nombre: [persona 141] accion:  [sin complicaciones] hora:  [381]
#  ---> nombre: [persona 150] accion:  [ llega al recinto] hora:  [381]
#   nombre: [persona 148] accion:  [fue vacunada ] hora:  [381]
#   nombre: [persona 149] accion:  [pasa el control] hora:  [382]
#   nombre: [persona 150] accion:  [pasa el control] hora:  [382]
#   nombre: [persona 140] accion:  [sin complicaciones] hora:  [383]
#  ---> nombre: [persona 151] accion:  [ llega al recinto] hora:  [383]
#   nombre: [persona 143] accion:  [sin complicaciones] hora:  [384]
#  ---> nombre: [persona 152] accion:  [ llega al recinto] hora:  [384]
#   nombre: [persona 151] accion:  [pasa el control] hora:  [384]
#   nombre: [persona 142] accion:  [sin complicaciones] hora:  [385]
#  ---> nombre: [persona 153] accion:  [ llega al recinto] hora:  [385]
#   nombre: [persona 152] accion:  [pasa el control] hora:  [385]
#   nombre: [persona 153] accion:  [pasa el control] hora:  [387]
#   nombre: [persona 144] accion:  [sin complicaciones] hora:  [389]
#  ---> nombre: [persona 154] accion:  [ llega al recinto] hora:  [389]
#   nombre: [persona 154] accion:  [pasa el control] hora:  [390]
#   nombre: [persona 149] accion:  [fue vacunada ] hora:  [391]
#   nombre: [persona 150] accion:  [fue vacunada ] hora:  [391]
#   nombre: [persona 145] accion:  [sin complicaciones] hora:  [393]
#  ---> nombre: [persona 155] accion:  [ llega al recinto] hora:  [393]
#   nombre: [persona 146] accion:  [sin complicaciones] hora:  [393]
#  ---> nombre: [persona 156] accion:  [ llega al recinto] hora:  [393]
#   nombre: [persona 151] accion:  [fue vacunada ] hora:  [393]
#   nombre: [persona 153] accion:  [fue vacunada ] hora:  [393]
#   nombre: [persona 147] accion:  [sin complicaciones] hora:  [395]
#  ---> nombre: [persona 157] accion:  [ llega al recinto] hora:  [395]
#   nombre: [persona 152] accion:  [fue vacunada ] hora:  [395]
#   nombre: [persona 154] accion:  [fue vacunada ] hora:  [395]
#   nombre: [persona 155] accion:  [pasa el control] hora:  [395]
#   nombre: [persona 156] accion:  [pasa el control] hora:  [395]
#   nombre: [persona 157] accion:  [pasa el control] hora:  [397]
#   nombre: [persona 148] accion:  [sin complicaciones] hora:  [401]
#  ---> nombre: [persona 158] accion:  [ llega al recinto] hora:  [401]
#   nombre: [persona 155] accion:  [fue vacunada ] hora:  [402]
#   nombre: [persona 157] accion:  [fue vacunada ] hora:  [402]
#   nombre: [persona 158] accion:  [pasa el control] hora:  [402]
#   nombre: [persona 156] accion:  [fue vacunada ] hora:  [405]
#   nombre: [persona 158] accion:  [fue vacunada ] hora:  [408]
#   nombre: [persona 149] accion:  [sin complicaciones] hora:  [411]
#  ---> nombre: [persona 159] accion:  [ llega al recinto] hora:  [411]
#   nombre: [persona 150] accion:  [sin complicaciones] hora:  [411]
#  ---> nombre: [persona 160] accion:  [ llega al recinto] hora:  [411]
#   nombre: [persona 159] accion:  [no pasa el control] hora:  [412]
#  ---> nombre: [persona 161] accion:  [ llega al recinto] hora:  [412]
#   nombre: [persona 151] accion:  [sin complicaciones] hora:  [413]
#  ---> nombre: [persona 162] accion:  [ llega al recinto] hora:  [413]
#   nombre: [persona 153] accion:  [sin complicaciones] hora:  [413]
#  ---> nombre: [persona 163] accion:  [ llega al recinto] hora:  [413]
#   nombre: [persona 160] accion:  [pasa el control] hora:  [414]
#   nombre: [persona 161] accion:  [pasa el control] hora:  [414]
#   nombre: [persona 152] accion:  [sin complicaciones] hora:  [415]
#  ---> nombre: [persona 164] accion:  [ llega al recinto] hora:  [415]
#   nombre: [persona 154] accion:  [sin complicaciones] hora:  [415]
#  ---> nombre: [persona 165] accion:  [ llega al recinto] hora:  [415]
#   nombre: [persona 162] accion:  [no pasa el control] hora:  [416]
#  ---> nombre: [persona 166] accion:  [ llega al recinto] hora:  [416]
#   nombre: [persona 163] accion:  [no pasa el control] hora:  [416]
#  ---> nombre: [persona 167] accion:  [ llega al recinto] hora:  [416]
#   nombre: [persona 164] accion:  [pasa el control] hora:  [417]
#   nombre: [persona 165] accion:  [pasa el control] hora:  [417]
#   nombre: [persona 166] accion:  [pasa el control] hora:  [417]
#   nombre: [persona 160] accion:  [fue vacunada ] hora:  [419]
#   nombre: [persona 161] accion:  [fue vacunada ] hora:  [419]
#   nombre: [persona 167] accion:  [pasa el control] hora:  [419]
#   nombre: [persona 155] accion:  [sin complicaciones] hora:  [422]
#  ---> nombre: [persona 168] accion:  [ llega al recinto] hora:  [422]
#   nombre: [persona 157] accion:  [sin complicaciones] hora:  [422]
#  ---> nombre: [persona 169] accion:  [ llega al recinto] hora:  [422]
#   nombre: [persona 164] accion:  [fue vacunada ] hora:  [422]
#   nombre: [persona 169] accion:  [pasa el control] hora:  [423]
#   nombre: [persona 156] accion:  [sin complicaciones] hora:  [425]
#  ---> nombre: [persona 170] accion:  [ llega al recinto] hora:  [425]
#   nombre: [persona 167] accion:  [fue vacunada ] hora:  [425]
#   nombre: [persona 168] accion:  [no pasa el control] hora:  [425]
#  ---> nombre: [persona 171] accion:  [ llega al recinto] hora:  [425]
#   nombre: [persona 165] accion:  [fue vacunada ] hora:  [427]
#   nombre: [persona 166] accion:  [fue vacunada ] hora:  [427]
#   nombre: [persona 171] accion:  [pasa el control] hora:  [427]
#   nombre: [persona 158] accion:  [sin complicaciones] hora:  [428]
#  ---> nombre: [persona 172] accion:  [ llega al recinto] hora:  [428]
#   nombre: [persona 170] accion:  [pasa el control] hora:  [428]
#   nombre: [persona 172] accion:  [pasa el control] hora:  [429]
#   nombre: [persona 169] accion:  [fue vacunada ] hora:  [430]
#   nombre: [persona 172] accion:  [fue vacunada ] hora:  [435]
#   nombre: [persona 171] accion:  [fue vacunada ] hora:  [436]
#   nombre: [persona 170] accion:  [fue vacunada ] hora:  [437]
#   nombre: [persona 160] accion:  [sin complicaciones] hora:  [439]
#  ---> nombre: [persona 173] accion:  [ llega al recinto] hora:  [439]
#   nombre: [persona 161] accion:  [sin complicaciones] hora:  [439]
#  ---> nombre: [persona 174] accion:  [ llega al recinto] hora:  [439]
#   nombre: [persona 173] accion:  [pasa el control] hora:  [441]
#   nombre: [persona 164] accion:  [sin complicaciones] hora:  [442]
#  ---> nombre: [persona 175] accion:  [ llega al recinto] hora:  [442]
#   nombre: [persona 174] accion:  [pasa el control] hora:  [442]
#   nombre: [persona 175] accion:  [pasa el control] hora:  [444]
#   nombre: [persona 167] accion:  [sin complicaciones] hora:  [445]
#  ---> nombre: [persona 176] accion:  [ llega al recinto] hora:  [445]
#   nombre: [persona 176] accion:  [pasa el control] hora:  [446]
#   nombre: [persona 165] accion:  [sin complicaciones] hora:  [447]
#  ---> nombre: [persona 177] accion:  [ llega al recinto] hora:  [447]
#   nombre: [persona 166] accion:  [sin complicaciones] hora:  [447]
#  ---> nombre: [persona 178] accion:  [ llega al recinto] hora:  [447]
#   nombre: [persona 177] accion:  [pasa el control] hora:  [448]
#   nombre: [persona 178] accion:  [no pasa el control] hora:  [448]
#  ---> nombre: [persona 179] accion:  [ llega al recinto] hora:  [448]
#   nombre: [persona 173] accion:  [fue vacunada ] hora:  [449]
#   nombre: [persona 174] accion:  [fue vacunada ] hora:  [449]
#   nombre: [persona 169] accion:  [sin complicaciones] hora:  [450]
#  ---> nombre: [persona 180] accion:  [ llega al recinto] hora:  [450]
#   nombre: [persona 179] accion:  [pasa el control] hora:  [450]
#   nombre: [persona 176] accion:  [fue vacunada ] hora:  [451]
#   nombre: [persona 175] accion:  [fue vacunada ] hora:  [452]
#   nombre: [persona 180] accion:  [pasa el control] hora:  [453]
#   nombre: [persona 177] accion:  [fue vacunada ] hora:  [454]
#   nombre: [persona 172] accion:  [sin complicaciones] hora:  [455]
#  ---> nombre: [persona 181] accion:  [ llega al recinto] hora:  [455]
#   nombre: [persona 171] accion:  [sin complicaciones] hora:  [456]
#  ---> nombre: [persona 182] accion:  [ llega al recinto] hora:  [456]
#   nombre: [persona 170] accion:  [sin complicaciones] hora:  [457]
#  ---> nombre: [persona 183] accion:  [ llega al recinto] hora:  [457]
#   nombre: [persona 182] accion:  [pasa el control] hora:  [457]
#   nombre: [persona 181] accion:  [pasa el control] hora:  [458]
#   nombre: [persona 179] accion:  [fue vacunada ] hora:  [459]
#   nombre: [persona 183] accion:  [pasa el control] hora:  [460]
#   nombre: [persona 180] accion:  [fue vacunada ] hora:  [461]
#   nombre: [persona 182] accion:  [fue vacunada ] hora:  [462]
#   nombre: [persona 181] accion:  [fue vacunada ] hora:  [464]
#   nombre: [persona 183] accion:  [fue vacunada ] hora:  [467]
#   nombre: [persona 173] accion:  [sin complicaciones] hora:  [469]
#  ---> nombre: [persona 184] accion:  [ llega al recinto] hora:  [469]
#   nombre: [persona 174] accion:  [sin complicaciones] hora:  [469]
#  ---> nombre: [persona 185] accion:  [ llega al recinto] hora:  [469]
#   nombre: [persona 184] accion:  [no pasa el control] hora:  [470]
#  ---> nombre: [persona 186] accion:  [ llega al recinto] hora:  [470]
#   nombre: [persona 176] accion:  [sin complicaciones] hora:  [471]
#  ---> nombre: [persona 187] accion:  [ llega al recinto] hora:  [471]
#   nombre: [persona 185] accion:  [pasa el control] hora:  [471]
#   nombre: [persona 175] accion:  [sin complicaciones] hora:  [472]
#  ---> nombre: [persona 188] accion:  [ llega al recinto] hora:  [472]
#   nombre: [persona 186] accion:  [pasa el control] hora:  [472]
#   nombre: [persona 187] accion:  [pasa el control] hora:  [472]
#   nombre: [persona 177] accion:  [sin complicaciones] hora:  [474]
#  ---> nombre: [persona 189] accion:  [ llega al recinto] hora:  [474]
#   nombre: [persona 188] accion:  [pasa el control] hora:  [474]
#   nombre: [persona 189] accion:  [pasa el control] hora:  [475]
#   nombre: [persona 185] accion:  [fue vacunada ] hora:  [477]
#   nombre: [persona 186] accion:  [fue vacunada ] hora:  [478]
#   nombre: [persona 179] accion:  [sin complicaciones] hora:  [479]
#  ---> nombre: [persona 190] accion:  [ llega al recinto] hora:  [479]
#   nombre: [persona 188] accion:  [fue vacunada ] hora:  [480]
#   nombre: [persona 180] accion:  [sin complicaciones] hora:  [481]
#  ---> nombre: [persona 191] accion:  [ llega al recinto] hora:  [481]
#   nombre: [persona 190] accion:  [pasa el control] hora:  [481]
#   nombre: [persona 182] accion:  [sin complicaciones] hora:  [482]
#  ---> nombre: [persona 192] accion:  [ llega al recinto] hora:  [482]
#   nombre: [persona 187] accion:  [fue vacunada ] hora:  [482]
#   nombre: [persona 191] accion:  [pasa el control] hora:  [483]
#   nombre: [persona 192] accion:  [pasa el control] hora:  [483]
#   nombre: [persona 181] accion:  [sin complicaciones] hora:  [484]
#  ---> nombre: [persona 193] accion:  [ llega al recinto] hora:  [484]
#   nombre: [persona 189] accion:  [fue vacunada ] hora:  [484]
#   nombre: [persona 193] accion:  [pasa el control] hora:  [485]
#   nombre: [persona 183] accion:  [sin complicaciones] hora:  [487]
#  ---> nombre: [persona 194] accion:  [ llega al recinto] hora:  [487]
#   nombre: [persona 190] accion:  [fue vacunada ] hora:  [489]
#   nombre: [persona 192] accion:  [fue vacunada ] hora:  [490]
#   nombre: [persona 194] accion:  [pasa el control] hora:  [490]
#   nombre: [persona 191] accion:  [fue vacunada ] hora:  [491]
#   nombre: [persona 193] accion:  [fue vacunada ] hora:  [494]
#   nombre: [persona 194] accion:  [fue vacunada ] hora:  [495]
#   nombre: [persona 185] accion:  [sin complicaciones] hora:  [497]
#  ---> nombre: [persona 195] accion:  [ llega al recinto] hora:  [497]
#   nombre: [persona 186] accion:  [sin complicaciones] hora:  [498]
#  ---> nombre: [persona 196] accion:  [ llega al recinto] hora:  [498]
#   nombre: [persona 188] accion:  [sin complicaciones] hora:  [500]
#  ---> nombre: [persona 197] accion:  [ llega al recinto] hora:  [500]
#   nombre: [persona 195] accion:  [no pasa el control] hora:  [500]
# ...
#   nombre: [persona 1254] accion:  [sin complicaciones] hora:  [3089]
#  ---> nombre: [persona 1263] accion:  [ llega al recinto] hora:  [3089]
#   nombre: [persona 1261] accion:  [pasa el control] hora:  [3090]
#   nombre: [persona 1262] accion:  [pasa el control] hora:  [3090]
#   nombre: [persona 1263] accion:  [pasa el control] hora:  [3092]
#   nombre: [persona 1253] accion:  [sin complicaciones] hora:  [3094]
#  ---> nombre: [persona 1264] accion:  [ llega al recinto] hora:  [3094]
#   nombre: [persona 1260] accion:  [fue vacunada ] hora:  [3095]
#   nombre: [persona 1261] accion:  [fue vacunada ] hora:  [3096]
#   nombre: [persona 1264] accion:  [pasa el control] hora:  [3096]
#   nombre: [persona 1262] accion:  [fue vacunada ] hora:  [3097]
#   nombre: [persona 1255] accion:  [sin complicaciones] hora:  [3098]
#  ---> nombre: [persona 1265] accion:  [ llega al recinto] hora:  [3098]
#   nombre: [persona 1257] accion:  [sin complicaciones] hora:  [3098]
#  ---> nombre: [persona 1266] accion:  [ llega al recinto] hora:  [3098]
#   nombre: [persona 1263] accion:  [fue vacunada ] hora:  [3098]
#   nombre: [persona 1266] accion:  [pasa el control] hora:  [3099]
#   nombre: [persona 1265] accion:  [pasa el control] hora:  [3101]
#   nombre: [persona 1256] accion:  [sin complicaciones] hora:  [3102]
#  ---> nombre: [persona 1267] accion:  [ llega al recinto] hora:  [3102]
#   nombre: [persona 1259] accion:  [sin complicaciones] hora:  [3103]
#  ---> nombre: [persona 1268] accion:  [ llega al recinto] hora:  [3103]
#   nombre: [persona 1267] accion:  [pasa el control] hora:  [3104]
#   nombre: [persona 1268] accion:  [pasa el control] hora:  [3105]
#   nombre: [persona 1258] accion:  [sin complicaciones] hora:  [3106]
#  ---> nombre: [persona 1269] accion:  [ llega al recinto] hora:  [3106]
#   nombre: [persona 1264] accion:  [fue vacunada ] hora:  [3106]
#   nombre: [persona 1266] accion:  [fue vacunada ] hora:  [3107]
#   nombre: [persona 1269] accion:  [pasa el control] hora:  [3107]
#   nombre: [persona 1267] accion:  [fue vacunada ] hora:  [3109]
#   nombre: [persona 1265] accion:  [fue vacunada ] hora:  [3110]
#   nombre: [persona 1269] accion:  [fue vacunada ] hora:  [3113]
#   nombre: [persona 1260] accion:  [sin complicaciones] hora:  [3115]
#  ---> nombre: [persona 1270] accion:  [ llega al recinto] hora:  [3115]
#   nombre: [persona 1268] accion:  [fue vacunada ] hora:  [3115]
#   nombre: [persona 1261] accion:  [sin complicaciones] hora:  [3116]
#  ---> nombre: [persona 1271] accion:  [ llega al recinto] hora:  [3116]
#   nombre: [persona 1262] accion:  [sin complicaciones] hora:  [3117]
#  ---> nombre: [persona 1272] accion:  [ llega al recinto] hora:  [3117]
#   nombre: [persona 1270] accion:  [pasa el control] hora:  [3117]
#   nombre: [persona 1263] accion:  [sin complicaciones] hora:  [3118]
#  ---> nombre: [persona 1273] accion:  [ llega al recinto] hora:  [3118]
#   nombre: [persona 1271] accion:  [no pasa el control] hora:  [3119]
#  ---> nombre: [persona 1274] accion:  [ llega al recinto] hora:  [3119]
#   nombre: [persona 1272] accion:  [pasa el control] hora:  [3119]
#   nombre: [persona 1273] accion:  [pasa el control] hora:  [3121]
#   nombre: [persona 1274] accion:  [pasa el control] hora:  [3121]
#   nombre: [persona 1272] accion:  [fue vacunada ] hora:  [3124]
#   nombre: [persona 1270] accion:  [fue vacunada ] hora:  [3125]
#   nombre: [persona 1264] accion:  [sin complicaciones] hora:  [3126]
#  ---> nombre: [persona 1275] accion:  [ llega al recinto] hora:  [3126]
#   nombre: [persona 1273] accion:  [fue vacunada ] hora:  [3126]
#   nombre: [persona 1266] accion:  [sin complicaciones] hora:  [3127]
#  ---> nombre: [persona 1276] accion:  [ llega al recinto] hora:  [3127]
#   nombre: [persona 1275] accion:  [pasa el control] hora:  [3128]
#   nombre: [persona 1276] accion:  [pasa el control] hora:  [3128]
#   nombre: [persona 1267] accion:  [sin complicaciones] hora:  [3129]
#  ---> nombre: [persona 1277] accion:  [ llega al recinto] hora:  [3129]
#   nombre: [persona 1265] accion:  [sin complicaciones] hora:  [3130]
#  ---> nombre: [persona 1278] accion:  [ llega al recinto] hora:  [3130]
#   nombre: [persona 1274] accion:  [fue vacunada ] hora:  [3130]
#   nombre: [persona 1277] accion:  [pasa el control] hora:  [3132]
#   nombre: [persona 1269] accion:  [sin complicaciones] hora:  [3133]
#  ---> nombre: [persona 1279] accion:  [ llega al recinto] hora:  [3133]
#   nombre: [persona 1278] accion:  [pasa el control] hora:  [3133]
#   nombre: [persona 1279] accion:  [no pasa el control] hora:  [3134]
#  ---> nombre: [persona 1280] accion:  [ llega al recinto] hora:  [3134]
#   nombre: [persona 1268] accion:  [sin complicaciones] hora:  [3135]
#  ---> nombre: [persona 1281] accion:  [ llega al recinto] hora:  [3135]
#   nombre: [persona 1275] accion:  [fue vacunada ] hora:  [3136]
#   nombre: [persona 1280] accion:  [no pasa el control] hora:  [3136]
#  ---> nombre: [persona 1282] accion:  [ llega al recinto] hora:  [3136]
#   nombre: [persona 1281] accion:  [pasa el control] hora:  [3137]
#   nombre: [persona 1282] accion:  [pasa el control] hora:  [3137]
#   nombre: [persona 1276] accion:  [fue vacunada ] hora:  [3138]
#   nombre: [persona 1278] accion:  [fue vacunada ] hora:  [3140]
#   nombre: [persona 1277] accion:  [fue vacunada ] hora:  [3142]
#   nombre: [persona 1272] accion:  [sin complicaciones] hora:  [3144]
#  ---> nombre: [persona 1283] accion:  [ llega al recinto] hora:  [3144]
#   nombre: [persona 1270] accion:  [sin complicaciones] hora:  [3145]
#  ---> nombre: [persona 1284] accion:  [ llega al recinto] hora:  [3145]
#   nombre: [persona 1282] accion:  [fue vacunada ] hora:  [3145]
#   nombre: [persona 1283] accion:  [pasa el control] hora:  [3145]
#   nombre: [persona 1273] accion:  [sin complicaciones] hora:  [3146]
#  ---> nombre: [persona 1285] accion:  [ llega al recinto] hora:  [3146]
#   nombre: [persona 1281] accion:  [fue vacunada ] hora:  [3146]
#   nombre: [persona 1284] accion:  [pasa el control] hora:  [3147]
#   nombre: [persona 1285] accion:  [pasa el control] hora:  [3148]
#   nombre: [persona 1274] accion:  [sin complicaciones] hora:  [3150]
#  ---> nombre: [persona 1286] accion:  [ llega al recinto] hora:  [3150]
#   nombre: [persona 1286] accion:  [pasa el control] hora:  [3151]
#   nombre: [persona 1283] accion:  [fue vacunada ] hora:  [3153]
#   nombre: [persona 1275] accion:  [sin complicaciones] hora:  [3156]
#  ---> nombre: [persona 1287] accion:  [ llega al recinto] hora:  [3156]
#   nombre: [persona 1284] accion:  [fue vacunada ] hora:  [3157]
#   nombre: [persona 1285] accion:  [fue vacunada ] hora:  [3157]
#   nombre: [persona 1286] accion:  [fue vacunada ] hora:  [3157]
#   nombre: [persona 1276] accion:  [sin complicaciones] hora:  [3158]
#  ---> nombre: [persona 1288] accion:  [ llega al recinto] hora:  [3158]
#   nombre: [persona 1287] accion:  [no pasa el control] hora:  [3158]
#  ---> nombre: [persona 1289] accion:  [ llega al recinto] hora:  [3158]
#   nombre: [persona 1278] accion:  [sin complicaciones] hora:  [3160]
#  ---> nombre: [persona 1290] accion:  [ llega al recinto] hora:  [3160]
#   nombre: [persona 1289] accion:  [pasa el control] hora:  [3160]
#   nombre: [persona 1288] accion:  [no pasa el control] hora:  [3161]
#  ---> nombre: [persona 1291] accion:  [ llega al recinto] hora:  [3161]
#   nombre: [persona 1290] accion:  [pasa el control] hora:  [3161]
#   nombre: [persona 1277] accion:  [sin complicaciones] hora:  [3162]
#  ---> nombre: [persona 1292] accion:  [ llega al recinto] hora:  [3162]
#   nombre: [persona 1292] accion:  [no pasa el control] hora:  [3163]
#  ---> nombre: [persona 1293] accion:  [ llega al recinto] hora:  [3163]
#   nombre: [persona 1291] accion:  [pasa el control] hora:  [3164]
#   nombre: [persona 1282] accion:  [sin complicaciones] hora:  [3165]
#  ---> nombre: [persona 1294] accion:  [ llega al recinto] hora:  [3165]
#   nombre: [persona 1293] accion:  [no pasa el control] hora:  [3165]
#  ---> nombre: [persona 1295] accion:  [ llega al recinto] hora:  [3165]
#   nombre: [persona 1281] accion:  [sin complicaciones] hora:  [3166]
#  ---> nombre: [persona 1296] accion:  [ llega al recinto] hora:  [3166]
#   nombre: [persona 1294] accion:  [pasa el control] hora:  [3166]
#   nombre: [persona 1295] accion:  [no pasa el control] hora:  [3166]
#  ---> nombre: [persona 1297] accion:  [ llega al recinto] hora:  [3166]
#   nombre: [persona 1297] accion:  [pasa el control] hora:  [3167]
#   nombre: [persona 1290] accion:  [fue vacunada ] hora:  [3168]
#   nombre: [persona 1296] accion:  [no pasa el control] hora:  [3168]
#  ---> nombre: [persona 1298] accion:  [ llega al recinto] hora:  [3168]
#   nombre: [persona 1289] accion:  [fue vacunada ] hora:  [3169]
#   nombre: [persona 1298] accion:  [no pasa el control] hora:  [3169]
#  ---> nombre: [persona 1299] accion:  [ llega al recinto] hora:  [3169]
#   nombre: [persona 1299] accion:  [pasa el control] hora:  [3170]
#   nombre: [persona 1291] accion:  [fue vacunada ] hora:  [3172]
#   nombre: [persona 1283] accion:  [sin complicaciones] hora:  [3173]
#  ---> nombre: [persona 1300] accion:  [ llega al recinto] hora:  [3173]
#   nombre: [persona 1294] accion:  [fue vacunada ] hora:  [3173]
#   nombre: [persona 1297] accion:  [fue vacunada ] hora:  [3173]
#   nombre: [persona 1299] accion:  [fue vacunada ] hora:  [3176]
#   nombre: [persona 1300] accion:  [pasa el control] hora:  [3176]
#   nombre: [persona 1284] accion:  [sin complicaciones] hora:  [3177]
#  ---> nombre: [persona 1301] accion:  [ llega al recinto] hora:  [3177]
#   nombre: [persona 1285] accion:  [sin complicaciones] hora:  [3177]
#  ---> nombre: [persona 1302] accion:  [ llega al recinto] hora:  [3177]
#   nombre: [persona 1286] accion:  [sin complicaciones] hora:  [3177]
#  ---> nombre: [persona 1303] accion:  [ llega al recinto] hora:  [3177]
#   nombre: [persona 1301] accion:  [pasa el control] hora:  [3178]
#   nombre: [persona 1302] accion:  [pasa el control] hora:  [3178]
#   nombre: [persona 1303] accion:  [pasa el control] hora:  [3180]
#   nombre: [persona 1301] accion:  [fue vacunada ] hora:  [3183]
#   nombre: [persona 1300] accion:  [fue vacunada ] hora:  [3184]
#   nombre: [persona 1302] accion:  [fue vacunada ] hora:  [3185]
#   nombre: [persona 1290] accion:  [sin complicaciones] hora:  [3188]
#  ---> nombre: [persona 1304] accion:  [ llega al recinto] hora:  [3188]
#   nombre: [persona 1303] accion:  [fue vacunada ] hora:  [3188]
#   nombre: [persona 1289] accion:  [sin complicaciones] hora:  [3189]
#  ---> nombre: [persona 1305] accion:  [ llega al recinto] hora:  [3189]
#   nombre: [persona 1305] accion:  [pasa el control] hora:  [3190]
#   nombre: [persona 1304] accion:  [no pasa el control] hora:  [3191]
#  ---> nombre: [persona 1306] accion:  [ llega al recinto] hora:  [3191]
#   nombre: [persona 1291] accion:  [sin complicaciones] hora:  [3192]
#  ---> nombre: [persona 1307] accion:  [ llega al recinto] hora:  [3192]
#   nombre: [persona 1306] accion:  [pasa el control] hora:  [3192]
#   nombre: [persona 1294] accion:  [sin complicaciones] hora:  [3193]
#  ---> nombre: [persona 1308] accion:  [ llega al recinto] hora:  [3193]
#   nombre: [persona 1297] accion:  [sin complicaciones] hora:  [3193]
#  ---> nombre: [persona 1309] accion:  [ llega al recinto] hora:  [3193]
#   nombre: [persona 1307] accion:  [pasa el control] hora:  [3193]
#   nombre: [persona 1309] accion:  [pasa el control] hora:  [3194]
#   nombre: [persona 1299] accion:  [sin complicaciones] hora:  [3196]
#  ---> nombre: [persona 1310] accion:  [ llega al recinto] hora:  [3196]
#   nombre: [persona 1308] accion:  [no pasa el control] hora:  [3196]
#  ---> nombre: [persona 1311] accion:  [ llega al recinto] hora:  [3196]
#   nombre: [persona 1306] accion:  [fue vacunada ] hora:  [3197]
#   nombre: [persona 1311] accion:  [pasa el control] hora:  [3197]
#   nombre: [persona 1305] accion:  [fue vacunada ] hora:  [3199]
#   nombre: [persona 1310] accion:  [pasa el control] hora:  [3199]
#   nombre: [persona 1309] accion:  [fue vacunada ] hora:  [3200]
#   nombre: [persona 1301] accion:  [sin complicaciones] hora:  [3203]
#  ---> nombre: [persona 1312] accion:  [ llega al recinto] hora:  [3203]
#   nombre: [persona 1307] accion:  [fue vacunada ] hora:  [3203]
#   nombre: [persona 1311] accion:  [fue vacunada ] hora:  [3203]
#   nombre: [persona 1300] accion:  [sin complicaciones] hora:  [3204]
#  ---> nombre: [persona 1313] accion:  [ llega al recinto] hora:  [3204]
#   nombre: [persona 1302] accion:  [sin complicaciones] hora:  [3205]
#  ---> nombre: [persona 1314] accion:  [ llega al recinto] hora:  [3205]
#   nombre: [persona 1312] accion:  [pasa el control] hora:  [3206]
#   nombre: [persona 1314] accion:  [pasa el control] hora:  [3206]
#   nombre: [persona 1313] accion:  [pasa el control] hora:  [3207]
#   nombre: [persona 1303] accion:  [sin complicaciones] hora:  [3208]
#  ---> nombre: [persona 1315] accion:  [ llega al recinto] hora:  [3208]
#   nombre: [persona 1310] accion:  [fue vacunada ] hora:  [3209]
#   nombre: [persona 1315] accion:  [pasa el control] hora:  [3211]
#   nombre: [persona 1312] accion:  [fue vacunada ] hora:  [3213]
#   nombre: [persona 1313] accion:  [fue vacunada ] hora:  [3213]
#   nombre: [persona 1314] accion:  [fue vacunada ] hora:  [3214]
#   nombre: [persona 1306] accion:  [sin complicaciones] hora:  [3217]
#  ---> nombre: [persona 1316] accion:  [ llega al recinto] hora:  [3217]
#   nombre: [persona 1316] accion:  [pasa el control] hora:  [3218]
#   nombre: [persona 1305] accion:  [sin complicaciones] hora:  [3219]
#  ---> nombre: [persona 1317] accion:  [ llega al recinto] hora:  [3219]
#   nombre: [persona 1309] accion:  [sin complicaciones] hora:  [3220]
#  ---> nombre: [persona 1318] accion:  [ llega al recinto] hora:  [3220]
#   nombre: [persona 1315] accion:  [fue vacunada ] hora:  [3220]
#   nombre: [persona 1317] accion:  [pasa el control] hora:  [3222]
#   nombre: [persona 1318] accion:  [pasa el control] hora:  [3222]
#   nombre: [persona 1307] accion:  [sin complicaciones] hora:  [3223]
#  ---> nombre: [persona 1319] accion:  [ llega al recinto] hora:  [3223]
#   nombre: [persona 1311] accion:  [sin complicaciones] hora:  [3223]
#  ---> nombre: [persona 1320] accion:  [ llega al recinto] hora:  [3223]
#   nombre: [persona 1320] accion:  [pasa el control] hora:  [3225]
#   nombre: [persona 1319] accion:  [pasa el control] hora:  [3226]
#   nombre: [persona 1316] accion:  [fue vacunada ] hora:  [3228]
#   nombre: [persona 1310] accion:  [sin complicaciones] hora:  [3229]
#  ---> nombre: [persona 1321] accion:  [ llega al recinto] hora:  [3229]
#   nombre: [persona 1321] accion:  [pasa el control] hora:  [3230]
#   nombre: [persona 1317] accion:  [fue vacunada ] hora:  [3231]
#   nombre: [persona 1318] accion:  [fue vacunada ] hora:  [3231]
#   nombre: [persona 1312] accion:  [sin complicaciones] hora:  [3233]
#  ---> nombre: [persona 1322] accion:  [ llega al recinto] hora:  [3233]
#   nombre: [persona 1313] accion:  [sin complicaciones] hora:  [3233]
#  ---> nombre: [persona 1323] accion:  [ llega al recinto] hora:  [3233]
#   nombre: [persona 1319] accion:  [fue vacunada ] hora:  [3233]
#   nombre: [persona 1314] accion:  [sin complicaciones] hora:  [3234]
#  ---> nombre: [persona 1324] accion:  [ llega al recinto] hora:  [3234]
#   nombre: [persona 1323] accion:  [pasa el control] hora:  [3234]
#   nombre: [persona 1320] accion:  [fue vacunada ] hora:  [3235]
#   nombre: [persona 1324] accion:  [pasa el control] hora:  [3235]
#   nombre: [persona 1322] accion:  [pasa el control] hora:  [3236]
# Simulacion realizada despues de 2 semanas
# [Mesa 0] ha vacunado a [108] personas
# [Mesa 1] ha vacunado a [109] personas
# [Mesa 2] ha vacunado a [107] personas
# [Mesa 3] ha vacunado a [107] personas
# [Mesa 4] ha vacunado a [107] personas
# [Mesa 5] ha vacunado a [108] personas
# [Mesa 6] ha vacunado a [109] personas
# [Mesa 7] ha vacunado a [108] personas
# [Mesa 8] ha vacunado a [108] personas
# [Mesa 9] ha vacunado a [107] personas
